# %% [markdown]
# # Create Figures for Paper
#
# Ce notebook permet de créer les figures du papier.

# %%
# ---------------------------- PREPARING NOTEBOOK ---------------------------- #
# Autoreload
# %load_ext autoreload
# %autoreload 2

# Random seed
import numpy as np
np.random.seed(42)

# External modules
import os
from IPython.display import display, Markdown, Latex, clear_output
from tqdm import notebook as tqdm

# Set global log level
import logging
logging.basicConfig(level=logging.INFO)
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

# Define PWD as the current git repository
import git
repo = git.Repo('.', search_parent_directories=True)
pwd = repo.working_dir
os.chdir(pwd)

# %% [markdown]
# ## Loading Data

# %% [markdown]
# ### OpenAI Evaluation

# %%
import pandas as pd

# Load metrics
path = os.path.join(
    pwd, "results", "difficulty_estimation", "OpenAiEvaluation", "metrics.csv"
)
openai_classification_metrics = pd.read_csv(path)
openai_classification_metrics
# Out:
#               dataset context               model  accuracy  f1 (macro)  \
# 0           sentences   CECRL  gpt-3.5-turbo-1106  0.897917    0.896970
# 1           sentences   empty  gpt-3.5-turbo-1106  0.866667    0.864868
# 2           sentences   CECRL         davinci-002  0.814583    0.812253
# 3                 ljl   empty  gpt-3.5-turbo-1106  0.733656    0.745840
# 4                 ljl   CECRL  gpt-3.5-turbo-1106  0.723971    0.735612
# 5           sentences   empty         davinci-002  0.825000    0.619090
# 6           sentences   empty         babbage-002  0.812500    0.609588
# 7           sentences   CECRL         babbage-002  0.812500    0.608993
# 8   french-difficulty   CECRL  gpt-3.5-turbo-1106  0.498958    0.423531
# 9                 ljl   empty         davinci-002  0.585956    0.337429
# 10                ljl   CECRL         davinci-002  0.610169    0.312199
# 11  french-difficulty   empty  gpt-3.5-turbo-1106  0.485417    0.292785
# 12  french-difficulty   CECRL         babbage-002  0.485417    0.289870
# 13  french-difficulty   empty         davinci-002  0.469792    0.280508
# 14                ljl   CECRL         babbage-002  0.585956    0.261941
# 15  french-difficulty   CECRL         davinci-002  0.469792    0.254112
# 16                ljl   empty         babbage-002  0.612591    0.250579
# 17  french-difficulty   empty         babbage-002  0.438542    0.187762
#
#     f1 (micro)  precision (macro)  precision (micro)  recall (macro)  \
# 0     0.897917           0.897494           0.897917        0.897917
# 1     0.866667           0.866231           0.866667        0.866667
# 2     0.814583           0.811908           0.814583        0.814583
# 3     0.733656           0.749340           0.733656        0.746278
# 4     0.723971           0.756418           0.723971        0.725500
# 5     0.825000           0.622441           0.825000        0.618750
# 6     0.812500           0.612527           0.812500        0.609375
# 7     0.812500           0.610264           0.812500        0.609375
# 8     0.498958           0.428613           0.498958        0.427679
# 9     0.585956           0.347085           0.585956        0.331162
# 10    0.610169           0.319176           0.610169        0.310129
# 11    0.485417           0.298541           0.485417        0.291250
# 12    0.485417           0.297746           0.485417        0.291250
# 13    0.469792           0.287537           0.469792        0.281875
# 14    0.585956           0.266914           0.585956        0.259139
# 15    0.469792           0.256299           0.469792        0.256250
# 16    0.612591           0.262796           0.612591        0.243034
# 17    0.438542           0.189873           0.438542        0.187946
#
#     recall (micro)
# 0         0.897917
# 1         0.866667
# 2         0.814583
# 3         0.733656
# 4         0.723971
# 5         0.825000
# 6         0.812500
# 7         0.812500
# 8         0.498958
# 9         0.585956
# 10        0.610169
# 11        0.485417
# 12        0.485417
# 13        0.469792
# 14        0.585956
# 15        0.469792
# 16        0.612591
# 17        0.438542

# %%
# Load GPT-3.5 predictions
ljl_best_predictions = pd.read_csv(
    os.path.join(
        pwd,
        "results",
        "DifficultyEstimationModel",
        f"test_ljl_empty_gpt-3.5-turbo-1106_prepared_for_fine_tuning_predictions.csv",
    )
)
sentences_best_predictions = pd.read_csv(
    os.path.join(
        pwd,
        "results",
        "DifficultyEstimationModel",
        f"test_sentences_CECRL_gpt-3.5-turbo-1106_prepared_for_fine_tuning_predictions.csv",
    )
)
french_difficulty_best_predictions = pd.read_csv(
    os.path.join(
        pwd,
        "results",
        "OpenSourceModelsEvaluation",
        "french_difficulty.csv",
    )
)

# Display
display(ljl_best_predictions)
display(sentences_best_predictions)
display(french_difficulty_best_predictions)
# Out:
#      context                                               user assistant  \
# 0        NaN  Le soleil se lève sur l' État indien du Mizora...    level4
# 1        NaN  — Non , nous ne pouvons pas ! Mani sentit les ...    level4
# 2        NaN  Manu essaye de se rappeler les nombreuses autr...    level4
# 3        NaN  Elles se réfugiaient alors dans un endroit ina...    level4
# 4        NaN  " Certains sons sont dangereux , nous devons d...    level3
# ..       ...                                                ...       ...
# 408      NaN  Prête pour aller à l' école ? Aujourd'hui , c'...    level2
# 409      NaN  « Na adore ces livres , se dit - il . C' est s...    level2
# 410      NaN  au creux des nuages l’ espoir un été passé san...    level3
# 411      NaN  Peut - être qu' une petite sieste ne lui ferai...    level4
# 412      NaN  Petite Grenouille vit dans un jardin . Tout le...    level2
#
#     predictions
# 0        level4
# 1        level4
# 2        level4
# 3        level4
# 4        level3
# ..          ...
# 408      level2
# 409      level2
# 410      level3
# 411      level4
# 412      level2
#
# [413 rows x 4 columns]
#                                                context  \
# 0    Vous êtes un évaluateur linguistique utilisant...
# 1    Vous êtes un évaluateur linguistique utilisant...
# 2    Vous êtes un évaluateur linguistique utilisant...
# 3    Vous êtes un évaluateur linguistique utilisant...
# 4    Vous êtes un évaluateur linguistique utilisant...
# ..                                                 ...
# 475  Vous êtes un évaluateur linguistique utilisant...
# 476  Vous êtes un évaluateur linguistique utilisant...
# 477  Vous êtes un évaluateur linguistique utilisant...
# 478  Vous êtes un évaluateur linguistique utilisant...
# 479  Vous êtes un évaluateur linguistique utilisant...
#
#                                                   user assistant predictions
# 0    Il y a des cyniques dans ce genre qui dînent à...        A1          C1
# 1    Ce cas me paraît être l'un des plus propres à ...        C2          C2
# 2    Et les experts de sonner l' alarme: «Il faut s...        C1          C1
# 3    Fonça dans la rue principale en direction de l...        B2          B2
# 4    Retirez-leur leur carte de visite, et ils perd...        C1          C1
# ..                                                 ...       ...         ...
# 475  Cet outil – impossible à fabriquer avec des mo...        A2          A2
# 476  Ayant dit, le gendarme s'inclina, son regard f...        B2          B2
# 477  Bref, nous jouissons de la vie comme jamais!» ...        C1          C1
# 478  Car, en instituant l'opération avec exactitude...        C2          C2
# 479  Là, il éprouva comme un choc en s’apercevant q...        A2          A2
#
# [480 rows x 4 columns]
#      Unnamed: 0                                           sentence difficulty  \
# 0             0  Dani, est-ce que tu t'es inscrite à ton concou...         A1
# 1             1  Elle passe aussi à la boulagerie et elle achèt...         A1
# 2             2                        J'ai un frère et une soeur.         A1
# 3             3                      Vous rentrez à quelle heure ?         A1
# 4             4                                Qu'en pensez-vous ?         A1
# ..          ...                                                ...        ...
# 955         955  Je ne savais pas que, bien plus tristement que...         C2
# 956         956  Comme Monsieur, un informaticien fondateur de ...         C2
# 957         957  Alors qu'au cours du Paléolithique, la diffusi...         C2
# 958         958  Ça vous débagoule des raisons, des accusations...         C2
# 959         959  Votre amitié me soutenait : sans cette amitié ...         C2
#
#     predictions
# 0            A2
# 1            A1
# 2            A1
# 3            A1
# 4            A1
# ..          ...
# 955          C2
# 956          C1
# 957          C2
# 958          C1
# 959          C1
#
# [960 rows x 4 columns]

# %% [markdown]
# ### Open-source Models Evaluation

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "OpenSourceModelsEvaluation",
    "bert_metrics.csv",
)
bert_classification_metrics = pd.read_csv(path)
bert_classification_metrics
# Out:
#           Unnamed: 0  accuracy  f1_macro  f1_micro  precision_macro  \
# 0          sentences  0.822917  0.821201  0.822917         0.826776
# 1                ljl  0.624697  0.631121  0.624697         0.626671
# 2  french_difficulty  0.522917  0.512580  0.522917         0.528225
#
#    precision_micro  recall_macro  recall_micro
# 0         0.822917      0.822917      0.822917
# 1         0.624697      0.640783      0.624697
# 2         0.522917      0.522917      0.522917

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "OpenSourceModelsEvaluation",
    "mistral_metrics.csv",
)
mistral_classification_metrics = pd.read_csv(path)
mistral_classification_metrics
# Out:
#              dataset     context  accuracy  f1_micro  precision_micro  \
# 0          sentences       CECRL    0.7479    0.7479           0.7479
# 1                ljl       CECRL    0.6368    0.6368           0.6368
# 2          sentences  no-context    0.6312    0.6312           0.6312
# 3  french-difficulty       CECRL    0.5125    0.5125           0.5125
# 4                ljl  no-context    0.4722    0.4722           0.4722
# 5  french-difficulty  no-context    0.3542    0.3542           0.3542
#
#    recall_micro
# 0        0.7479
# 1        0.6368
# 2        0.6312
# 3        0.5125
# 4        0.4722
# 5        0.3542

# %% [markdown]
# ### Pairwise Mismatched Evaluation

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "PairwiseMismatch",
    "readability_index_classification_metrics.csv",
)
readability_index_classification_metrics = pd.read_csv(path)
readability_index_classification_metrics
# Out:
#              dataset model  accuracy  f1_micro  precision_micro  recall_micro
# 0                ljl   gfi    0.4504    0.4504           0.4504        0.4504
# 1                ljl  fkgl    0.4213    0.4213           0.4213        0.4213
# 2                ljl   ari    0.3995    0.3995           0.3995        0.3995
# 3  french-difficulty  fkgl    0.3458    0.3458           0.3458        0.3458
# 4          sentences   ari    0.3438    0.3438           0.3438        0.3438
# 5  french-difficulty   gfi    0.3417    0.3417           0.3417        0.3417
# 6  french-difficulty   ari    0.3417    0.3417           0.3417        0.3417
# 7          sentences  fkgl    0.3354    0.3354           0.3354        0.3354
# 8          sentences   gfi    0.3229    0.3229           0.3229        0.3229

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "PairwiseMismatch",
    "readability_index_pairwise_mismatch.csv",
)
readability_index_pairwise_mismatch = pd.read_csv(path)
readability_index_pairwise_mismatch
# Out:
#              dataset model  pairwise_mismatch
# 0                ljl   gfi            44.0969
# 1                ljl   ari            47.0944
# 2                ljl  fkgl            54.5375
# 3          sentences   ari            88.2375
# 4          sentences  fkgl            99.3167
# 5          sentences   gfi           101.9583
# 6  french-difficulty   ari           111.5646
# 7  french-difficulty  fkgl           112.3771
# 8  french-difficulty   gfi           112.6271

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "PairwiseMismatch",
    "bert_pairwise_mismatch.csv",
)
bert_pairwise_mismatch = pd.read_csv(path)
bert_pairwise_mismatch
# Out:
#           Unnamed: 0  Pairwise mismatch
# 0                ljl            13.9516
# 1          sentences            22.2125
# 2  french_difficulty            36.9812

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "PairwiseMismatch",
    "openai_pairwise_mismatch.csv",
)
openai_pairwise_mismatch = pd.read_csv(path)
openai_pairwise_mismatch
# Out:
#               dataset context               model  pairwise_mismatch
# 0                 ljl   empty  gpt-3.5-turbo-1106             9.2736
# 1                 ljl   CECRL  gpt-3.5-turbo-1106            11.0605
# 2           sentences   CECRL  gpt-3.5-turbo-1106            13.1125
# 3           sentences   empty  gpt-3.5-turbo-1106            18.1083
# 4                 ljl   empty         babbage-002            18.3341
# 5                 ljl   CECRL         davinci-002            18.6925
# 6           sentences   empty         davinci-002            20.9042
# 7                 ljl   empty         davinci-002            21.0896
# 8           sentences   empty         babbage-002            21.2625
# 9                 ljl   CECRL         babbage-002            23.7482
# 10          sentences   CECRL         davinci-002            23.8250
# 11          sentences   CECRL         babbage-002            25.6417
# 12  french-difficulty   CECRL  gpt-3.5-turbo-1106            51.9792
# 13  french-difficulty   CECRL         babbage-002            60.9188
# 14  french-difficulty   empty  gpt-3.5-turbo-1106            61.1250
# 15  french-difficulty   CECRL         davinci-002            66.4396
# 16  french-difficulty   empty         davinci-002            76.5188
# 17  french-difficulty   empty         babbage-002            86.4021

# %%
# Load metrics
path = os.path.join(
    pwd,
    "results",
    "difficulty_estimation",
    "PairwiseMismatch",
    "mistral_pairwise_mismatch.csv",
)
mistral_pairwise_mismatch = pd.read_csv(path)
mistral_pairwise_mismatch
# Out:
#                      Unnamed: 0  Pairwise mismatch
# 0                     ljl_CECRL            13.6223
# 1                ljl_no-context            29.9855
# 2  french_difficulty_no-context            39.3771
# 3               sentences_CECRL            39.7625
# 4       french_difficulty_CECRL            48.4146
# 5          sentences_no-context            61.7542

# %% [markdown]
# ## Figures Creation

# %%
# Load metrics
metrics = {
    "readability_index_classification_metrics": readability_index_classification_metrics.copy(),
    "bert_classification_metrics": bert_classification_metrics.copy(),
    "mistral_classification_metrics": mistral_classification_metrics.copy(),
    "openai_classification_metrics": openai_classification_metrics.copy(),
    "readability_index_pairwise_mismatch": readability_index_pairwise_mismatch.copy(),
    "bert_pairwise_mismatch": bert_pairwise_mismatch.copy(),
    "mistral_pairwise_mismatch": mistral_pairwise_mismatch.copy(),
    "openai_pairwise_mismatch": openai_pairwise_mismatch.copy(),
}

# Format all dataframe to have the same columns in classification metrics
## Readability index
metrics["readability_index_classification_metrics"].columns = [
    "dataset",
    "model",
    "accuracy",
    "f1 (micro)",
    "precision (micro)",
    "recall (micro)",
]
metrics["readability_index_classification_metrics"]["context"] = "empty"
## CamemBERT
metrics["bert_classification_metrics"].drop(
    columns=["precision_macro", "recall_macro", "f1_macro"], inplace=True
)
metrics["bert_classification_metrics"].columns = [
    "dataset",
    "accuracy",
    "f1 (micro)",
    "precision (micro)",
    "recall (micro)",
]
metrics["bert_classification_metrics"]["model"] = "CamemBERT"
metrics["bert_classification_metrics"]["context"] = "empty"
## Mistral
metrics["mistral_classification_metrics"].columns = [
    "dataset",
    "context",
    "accuracy",
    "f1 (micro)",
    "precision (micro)",
    "recall (micro)",
]
metrics["mistral_classification_metrics"]["model"] = "Mistral-7B"
## OpenAI
metrics["openai_classification_metrics"].drop(
    columns=["f1 (macro)", "precision (macro)", "recall (macro)"], inplace=True
)
metrics["openai_classification_metrics"].columns = [
    "dataset",
    "context",
    "model",
    "accuracy",
    "f1 (micro)",
    "precision (micro)",
    "recall (micro)",
]

# Format all dataframe to have the same columns in pairwise mismatch
## Readability index
metrics["readability_index_pairwise_mismatch"]["context"] = "empty"
metrics["readability_index_pairwise_mismatch"].columns = [
    "dataset",
    "model",
    "pairwise mismatch",
    "context",
]
## CamemBERT
metrics["bert_pairwise_mismatch"].columns = [
    "dataset",
    "pairwise mismatch",
]
metrics["bert_pairwise_mismatch"]["model"] = "CamemBERT"
metrics["bert_pairwise_mismatch"]["context"] = "empty"
## Mistral
metrics["mistral_pairwise_mismatch"].iloc[:, 0] = (
    metrics["mistral_pairwise_mismatch"]
    .iloc[:, 0]
    .str.replace("french_difficulty", "french-difficulty")
)
metrics["mistral_pairwise_mismatch"]["dataset"] = (
    metrics["mistral_pairwise_mismatch"].iloc[:, 0].apply(lambda x: x.split("_")[0])
)
metrics["mistral_pairwise_mismatch"]["context"] = (
    metrics["mistral_pairwise_mismatch"].iloc[:, 0].apply(lambda x: x.split("_")[1])
)
metrics["mistral_pairwise_mismatch"].drop(
    columns=[metrics["mistral_pairwise_mismatch"].columns[0]], inplace=True
)
metrics["mistral_pairwise_mismatch"].columns = [
    "pairwise mismatch",
    "dataset",
    "context",
]
metrics["mistral_pairwise_mismatch"]["model"] = "Mistral-7B"
## OpenAI
metrics["openai_pairwise_mismatch"].columns = [
    "dataset",
    "context",
    "model",
    "pairwise mismatch",
]

# Merge classification metrics and pairwise mismatch
merged_metrics = {}
for key, metric in metrics.items():
    table = "_".join(key.split("_")[:-2])
    if table not in merged_metrics.keys():
        merged_metrics[table] = metric.copy()
    else:
        merged_metrics[table] = merged_metrics[table].merge(
            metric, on=["dataset", "model", "context"]
        )

# Concatenate all metrics
concatenated_metrics = pd.concat(merged_metrics.values(), ignore_index=True)

# Replace "no-context" by "empty" and "french_difficulty" by "french-difficulty"
concatenated_metrics["context"] = concatenated_metrics["context"].replace(
    "no-context", "empty"
)
concatenated_metrics["dataset"] = concatenated_metrics["dataset"].replace(
    "french_difficulty", "french-difficulty"
)

# Reorder columns
concatenated_metrics = concatenated_metrics[
    [
        "model",
        "context",
        "dataset",
        "pairwise mismatch",
        "accuracy",
        "f1 (micro)",
        "precision (micro)",
        "recall (micro)",
    ]
]

# Remove "babbage-002" model
concatenated_metrics = concatenated_metrics[
    concatenated_metrics["model"] != "babbage-002"
]

# Capitalize model names
concatenated_metrics["model"] = concatenated_metrics["model"].apply(
    lambda x: x.replace("gpt", "GPT")
    .replace("bert", "BERT")
    .replace("mistral", "Mistral")
    .replace("davinci", "Davinci")
    .replace("gfi", "GFI")
    .replace("ari", "ARI")
    .replace("fkgl", "FKGL")
)

# Round all metrics to 2 decimals
concatenated_metrics = concatenated_metrics.round(2)

# Sort by pairwise mismatch
concatenated_metrics.sort_values(by=["pairwise mismatch"], inplace=True)

# Replace context
concatenated_metrics["context"] = (
    concatenated_metrics["context"].replace("empty", "-").replace("CECRL", "\checkmark")
)

# Rename datasets
concatenated_metrics["dataset"] = (
    concatenated_metrics["dataset"]
    .replace("french-difficulty", "SentencesBooks")
    .replace("ljl", "LjL")
    .replace("sentences", "SentencesInternet")
)

# Split by dataset
datasets_metrics = {}
for dataset in concatenated_metrics["dataset"].unique():
    # Split by dataset
    datasets_metrics[dataset] = (
        concatenated_metrics[concatenated_metrics["dataset"] == dataset]
        .copy()
        .drop(columns=["dataset"])
    ).reset_index(drop=True)

    # Set multi-index from model and context
    datasets_metrics[dataset].set_index(["model", "context"], inplace=True)


for dataset, metric in datasets_metrics.items():
    display(Markdown(f"### {dataset}"))
    with pd.option_context("display.max_rows", None, "display.max_columns", None):
        display(metric)
# Out:
# ### LjL
#                                pairwise mismatch  accuracy  f1 (micro)  \
# model              context
# GPT-3.5-turbo-1106 -                        9.27      0.73        0.73
#                    \checkmark              11.06      0.72        0.72
# Mistral-7B         \checkmark              13.62      0.64        0.64
# CamemBERT          -                       13.95      0.62        0.62
# Davinci-002        \checkmark              18.69      0.61        0.61
#                    -                       21.09      0.59        0.59
# Mistral-7B         -                       29.99      0.47        0.47
# GFI                -                       44.10      0.45        0.45
# ARI                -                       47.09      0.40        0.40
# FKGL               -                       54.54      0.42        0.42
#
#                                precision (micro)  recall (micro)
# model              context
# GPT-3.5-turbo-1106 -                        0.73            0.73
#                    \checkmark               0.72            0.72
# Mistral-7B         \checkmark               0.64            0.64
# CamemBERT          -                        0.62            0.62
# Davinci-002        \checkmark               0.61            0.61
#                    -                        0.59            0.59
# Mistral-7B         -                        0.47            0.47
# GFI                -                        0.45            0.45
# ARI                -                        0.40            0.40
# FKGL               -                        0.42            0.42
# ### SentencesInternet
#                                pairwise mismatch  accuracy  f1 (micro)  \
# model              context
# GPT-3.5-turbo-1106 \checkmark              13.11      0.90        0.90
#                    -                       18.11      0.87        0.87
# Davinci-002        -                       20.90      0.82        0.82
# CamemBERT          -                       22.21      0.82        0.82
# Davinci-002        \checkmark              23.82      0.81        0.81
# Mistral-7B         \checkmark              39.76      0.75        0.75
#                    -                       61.75      0.63        0.63
# ARI                -                       88.24      0.34        0.34
# FKGL               -                       99.32      0.34        0.34
# GFI                -                      101.96      0.32        0.32
#
#                                precision (micro)  recall (micro)
# model              context
# GPT-3.5-turbo-1106 \checkmark               0.90            0.90
#                    -                        0.87            0.87
# Davinci-002        -                        0.82            0.82
# CamemBERT          -                        0.82            0.82
# Davinci-002        \checkmark               0.81            0.81
# Mistral-7B         \checkmark               0.75            0.75
#                    -                        0.63            0.63
# ARI                -                        0.34            0.34
# FKGL               -                        0.34            0.34
# GFI                -                        0.32            0.32
# ### SentencesBooks
#                                pairwise mismatch  accuracy  f1 (micro)  \
# model              context
# CamemBERT          -                       36.98      0.52        0.52
# Mistral-7B         -                       39.38      0.35        0.35
#                    \checkmark              48.41      0.51        0.51
# GPT-3.5-turbo-1106 \checkmark              51.98      0.50        0.50
#                    -                       61.12      0.49        0.49
# Davinci-002        \checkmark              66.44      0.47        0.47
#                    -                       76.52      0.47        0.47
# ARI                -                      111.56      0.34        0.34
# FKGL               -                      112.38      0.35        0.35
# GFI                -                      112.63      0.34        0.34
#
#                                precision (micro)  recall (micro)
# model              context
# CamemBERT          -                        0.52            0.52
# Mistral-7B         -                        0.35            0.35
#                    \checkmark               0.51            0.51
# GPT-3.5-turbo-1106 \checkmark               0.50            0.50
#                    -                        0.49            0.49
# Davinci-002        \checkmark               0.47            0.47
#                    -                        0.47            0.47
# ARI                -                        0.34            0.34
# FKGL               -                        0.35            0.35
# GFI                -                        0.34            0.34

# %%
# Supposons que datasets_metrics est une liste de DataFrames
datasets_metrics_df = pd.concat([df['accuracy'] for df in datasets_metrics.values()], axis=1)
datasets_metrics_df.columns = datasets_metrics.keys()

# Sort by mean ranking
datasets_metrics_df["Ranking"] = datasets_metrics_df.rank(axis=0, ascending=False).mean(axis=1)
datasets_metrics_df = datasets_metrics_df.sort_values(by="Ranking").drop(columns="Ranking")
datasets_metrics_df
# Out:
#                                 LjL  SentencesInternet  SentencesBooks
# model              context
# GPT-3.5-turbo-1106 \checkmark  0.72               0.90            0.50
#                    -           0.73               0.87            0.49
# CamemBERT          -           0.62               0.82            0.52
# Mistral-7B         \checkmark  0.64               0.75            0.51
# Davinci-002        -           0.59               0.82            0.47
#                    \checkmark  0.61               0.81            0.47
# Mistral-7B         -           0.47               0.63            0.35
# FKGL               -           0.42               0.34            0.35
# GFI                -           0.45               0.32            0.34
# ARI                -           0.40               0.34            0.34

# %%
predictions = {
    "LjL": ljl_best_predictions,
    "SentencesInternet": sentences_best_predictions,
    "SentencesBooks": french_difficulty_best_predictions,
}

# Format all dataframe to have the same columns
## LJL
predictions["LjL"] = predictions["LjL"][["assistant", "predictions"]]
predictions["LjL"].columns = ["y_true", "y_pred"]
## Sentences
predictions["SentencesInternet"] = predictions["SentencesInternet"][
    ["assistant", "predictions"]
]
predictions["SentencesInternet"].columns = ["y_true", "y_pred"]
## French difficulty
predictions["SentencesBooks"] = predictions["SentencesBooks"][
    ["difficulty", "predictions"]
]
predictions["SentencesBooks"].columns = ["y_true", "y_pred"]

# %% [markdown]
# ## Exporting as Latex

# %% [markdown]
# ### Tables

# %%
# Mute pandas warning
import warnings
import seaborn as sns

warnings.simplefilter(action="ignore", category=FutureWarning)


# Bold best results
def highlight_best(x):
    # Create empty dataframe
    df = pd.DataFrame("", index=x.index, columns=x.columns)

    # Bold max of accuracy	f1 (micro)	precision (micro)	recall (micro)
    for metric in ["accuracy", "f1 (micro)", "precision (micro)", "recall (micro)"]:
        df[metric].loc[x[metric].idxmax()] += "font-weight: bold; color: #FF9999;"

    return df


for dataset_name, df in datasets_metrics.items():
    # Remove pairwise mismatch
    df = df.drop(columns=["pairwise mismatch"])
    # Sort by accuracy
    df = df.sort_values(by=["accuracy"], ascending=False)

    styled_df = (
        df.style.background_gradient(cmap=sns.light_palette("green", as_cmap=True))
        .apply(highlight_best, axis=None)
        .applymap_index(lambda v: "font-weight: bold;", axis="columns")
        .applymap_index(lambda v: "font-weight: bold;", axis="rows")
        .format(decimal=".", thousands=",", precision=2)
    )
    display(styled_df)
    path = os.path.join(pwd, "figures", "difficulty_estimation", f"{dataset_name}.tex")
    if not os.path.exists(os.path.dirname(path)):
        os.makedirs(os.path.dirname(path))
    latex = styled_df.to_latex(
        caption=(f"Metrics for the {dataset_name} dataset"),
        clines="skip-last;data",
        convert_css=True,
        position_float="centering",
        multicol_align="|c|",
        hrules=True,
    )

    # Add \begin{adjustbox}{center}
    latex = latex.replace(
        "\\begin{tabular}", "\\begin{adjustbox}{center}\n\\begin{tabular}"
    ).replace(
        "\\end{tabular}",
        f"\\end{{tabular}}\n\\label{{tab:{dataset_name}_metrics}}\n\\end{{adjustbox}}",
    )

    # Force position of table
    latex = latex.replace("\\begin{table}", "\\begin{table}[!h]")

    print(latex)
# Out:
# <style type="text/css">
# #T_74e75_row0_col0, #T_74e75_row0_col1, #T_74e75_row0_col2, #T_74e75_row0_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
#   font-weight: bold;
#   color: #FF9999;
# }
# #T_74e75_row1_col0, #T_74e75_row1_col1, #T_74e75_row1_col2, #T_74e75_row1_col3 {
#   background-color: #068306;
#   color: #f1f1f1;
# }
# #T_74e75_row2_col0, #T_74e75_row2_col1, #T_74e75_row2_col2, #T_74e75_row2_col3 {
#   background-color: #3f9f3f;
#   color: #f1f1f1;
# }
# #T_74e75_row3_col0, #T_74e75_row3_col1, #T_74e75_row3_col2, #T_74e75_row3_col3 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_74e75_row4_col0, #T_74e75_row4_col1, #T_74e75_row4_col2, #T_74e75_row4_col3 {
#   background-color: #56aa56;
#   color: #f1f1f1;
# }
# #T_74e75_row5_col0, #T_74e75_row5_col1, #T_74e75_row5_col2, #T_74e75_row5_col3 {
#   background-color: #63b163;
#   color: #f1f1f1;
# }
# #T_74e75_row6_col0, #T_74e75_row6_col1, #T_74e75_row6_col2, #T_74e75_row6_col3 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_74e75_row7_col0, #T_74e75_row7_col1, #T_74e75_row7_col2, #T_74e75_row7_col3 {
#   background-color: #c8e2c8;
#   color: #000000;
# }
# #T_74e75_row8_col0, #T_74e75_row8_col1, #T_74e75_row8_col2, #T_74e75_row8_col3 {
#   background-color: #ddecdd;
#   color: #000000;
# }
# #T_74e75_row9_col0, #T_74e75_row9_col1, #T_74e75_row9_col2, #T_74e75_row9_col3 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_74e75_level0_row0, #T_74e75_level1_row0, #T_74e75_level1_row1, #T_74e75_level0_row2, #T_74e75_level1_row2, #T_74e75_level0_row3, #T_74e75_level1_row3, #T_74e75_level0_row4, #T_74e75_level1_row4, #T_74e75_level1_row5, #T_74e75_level0_row6, #T_74e75_level1_row6, #T_74e75_level0_row7, #T_74e75_level1_row7, #T_74e75_level0_row8, #T_74e75_level1_row8, #T_74e75_level0_row9, #T_74e75_level1_row9 {
#   font-weight: bold;
# }
# #T_74e75_level0_col0, #T_74e75_level0_col1, #T_74e75_level0_col2, #T_74e75_level0_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_74e75">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74e75_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_74e75_level0_col1" class="col_heading level0 col1" >f1 (micro)</th>
#       <th id="T_74e75_level0_col2" class="col_heading level0 col2" >precision (micro)</th>
#       <th id="T_74e75_level0_col3" class="col_heading level0 col3" >recall (micro)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >context</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74e75_level0_row0" class="row_heading level0 row0" rowspan="2">GPT-3.5-turbo-1106</th>
#       <th id="T_74e75_level1_row0" class="row_heading level1 row0" >-</th>
#       <td id="T_74e75_row0_col0" class="data row0 col0" >0.73</td>
#       <td id="T_74e75_row0_col1" class="data row0 col1" >0.73</td>
#       <td id="T_74e75_row0_col2" class="data row0 col2" >0.73</td>
#       <td id="T_74e75_row0_col3" class="data row0 col3" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_74e75_level1_row1" class="row_heading level1 row1" >\checkmark</th>
#       <td id="T_74e75_row1_col0" class="data row1 col0" >0.72</td>
#       <td id="T_74e75_row1_col1" class="data row1 col1" >0.72</td>
#       <td id="T_74e75_row1_col2" class="data row1 col2" >0.72</td>
#       <td id="T_74e75_row1_col3" class="data row1 col3" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_74e75_level0_row2" class="row_heading level0 row2" >Mistral-7B</th>
#       <th id="T_74e75_level1_row2" class="row_heading level1 row2" >\checkmark</th>
#       <td id="T_74e75_row2_col0" class="data row2 col0" >0.64</td>
#       <td id="T_74e75_row2_col1" class="data row2 col1" >0.64</td>
#       <td id="T_74e75_row2_col2" class="data row2 col2" >0.64</td>
#       <td id="T_74e75_row2_col3" class="data row2 col3" >0.64</td>
#     </tr>
#     <tr>
#       <th id="T_74e75_level0_row3" class="row_heading level0 row3" >CamemBERT</th>
#       <th id="T_74e75_level1_row3" class="row_heading level1 row3" >-</th>
#       <td id="T_74e75_row3_col0" class="data row3 col0" >0.62</td>
#       <td id="T_74e75_row3_col1" class="data row3 col1" >0.62</td>
#       <td id="T_74e75_row3_col2" class="data row3 col2" >0.62</td>
#       <td id="T_74e75_row3_col3" class="data row3 col3" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_74e75_level0_row4" class="row_heading level0 row4" rowspan="2">Davinci-002</th>
#       <th id="T_74e75_level1_row4" class="row_heading level1 row4" >\checkmark</th>
#       <td id="T_74e75_row4_col0" class="data row4 col0" >0.61</td>
#       <td id="T_74e75_row4_col1" class="data row4 col1" >0.61</td>
#       <td id="T_74e75_row4_col2" class="data row4 col2" >0.61</td>
#       <td id="T_74e75_row4_col3" class="data row4 col3" >0.61</td>
#     </tr>
#     <tr>
#       <th id="T_74e75_level1_row5" class="row_heading level1 row5" >-</th>
#       <td id="T_74e75_row5_col0" class="data row5 col0" >0.59</td>
#       <td id="T_74e75_row5_col1" class="data row5 col1" >0.59</td>
#       <td id="T_74e75_row5_col2" class="data row5 col2" >0.59</td>
#       <td id="T_74e75_row5_col3" class="data row5 col3" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_74e75_level0_row6" class="row_heading level0 row6" >Mistral-7B</th>
#       <th id="T_74e75_level1_row6" class="row_heading level1 row6" >-</th>
#       <td id="T_74e75_row6_col0" class="data row6 col0" >0.47</td>
#       <td id="T_74e75_row6_col1" class="data row6 col1" >0.47</td>
#       <td id="T_74e75_row6_col2" class="data row6 col2" >0.47</td>
#       <td id="T_74e75_row6_col3" class="data row6 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_74e75_level0_row7" class="row_heading level0 row7" >GFI</th>
#       <th id="T_74e75_level1_row7" class="row_heading level1 row7" >-</th>
#       <td id="T_74e75_row7_col0" class="data row7 col0" >0.45</td>
#       <td id="T_74e75_row7_col1" class="data row7 col1" >0.45</td>
#       <td id="T_74e75_row7_col2" class="data row7 col2" >0.45</td>
#       <td id="T_74e75_row7_col3" class="data row7 col3" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_74e75_level0_row8" class="row_heading level0 row8" >FKGL</th>
#       <th id="T_74e75_level1_row8" class="row_heading level1 row8" >-</th>
#       <td id="T_74e75_row8_col0" class="data row8 col0" >0.42</td>
#       <td id="T_74e75_row8_col1" class="data row8 col1" >0.42</td>
#       <td id="T_74e75_row8_col2" class="data row8 col2" >0.42</td>
#       <td id="T_74e75_row8_col3" class="data row8 col3" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_74e75_level0_row9" class="row_heading level0 row9" >ARI</th>
#       <th id="T_74e75_level1_row9" class="row_heading level1 row9" >-</th>
#       <td id="T_74e75_row9_col0" class="data row9 col0" >0.40</td>
#       <td id="T_74e75_row9_col1" class="data row9 col1" >0.40</td>
#       <td id="T_74e75_row9_col2" class="data row9 col2" >0.40</td>
#       <td id="T_74e75_row9_col3" class="data row9 col3" >0.40</td>
#     </tr>
#   </tbody>
# </table>
# \begin{table}[!h]
# \centering
# \caption{Metrics for the LjL dataset}
# \begin{adjustbox}{center}
# \begin{tabular}{llrrrr}
# \toprule
#  &  & \bfseries accuracy & \bfseries f1 (micro) & \bfseries precision (micro) & \bfseries recall (micro) \\
# model & context &  &  &  &  \\
# \midrule
# \multirow[c]{2}{*}{\bfseries GPT-3.5-turbo-1106} & \bfseries - & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.73 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.73 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.73 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.73 \\
# \bfseries  & \bfseries \checkmark & {\cellcolor[HTML]{068306}} \color[HTML]{F1F1F1} 0.72 & {\cellcolor[HTML]{068306}} \color[HTML]{F1F1F1} 0.72 & {\cellcolor[HTML]{068306}} \color[HTML]{F1F1F1} 0.72 & {\cellcolor[HTML]{068306}} \color[HTML]{F1F1F1} 0.72 \\
# \cline{1-6}
# \bfseries Mistral-7B & \bfseries \checkmark & {\cellcolor[HTML]{3F9F3F}} \color[HTML]{F1F1F1} 0.64 & {\cellcolor[HTML]{3F9F3F}} \color[HTML]{F1F1F1} 0.64 & {\cellcolor[HTML]{3F9F3F}} \color[HTML]{F1F1F1} 0.64 & {\cellcolor[HTML]{3F9F3F}} \color[HTML]{F1F1F1} 0.64 \\
# \cline{1-6}
# \bfseries CamemBERT & \bfseries - & {\cellcolor[HTML]{4EA64E}} \color[HTML]{F1F1F1} 0.62 & {\cellcolor[HTML]{4EA64E}} \color[HTML]{F1F1F1} 0.62 & {\cellcolor[HTML]{4EA64E}} \color[HTML]{F1F1F1} 0.62 & {\cellcolor[HTML]{4EA64E}} \color[HTML]{F1F1F1} 0.62 \\
# \cline{1-6}
# \multirow[c]{2}{*}{\bfseries Davinci-002} & \bfseries \checkmark & {\cellcolor[HTML]{56AA56}} \color[HTML]{F1F1F1} 0.61 & {\cellcolor[HTML]{56AA56}} \color[HTML]{F1F1F1} 0.61 & {\cellcolor[HTML]{56AA56}} \color[HTML]{F1F1F1} 0.61 & {\cellcolor[HTML]{56AA56}} \color[HTML]{F1F1F1} 0.61 \\
# \bfseries  & \bfseries - & {\cellcolor[HTML]{63B163}} \color[HTML]{F1F1F1} 0.59 & {\cellcolor[HTML]{63B163}} \color[HTML]{F1F1F1} 0.59 & {\cellcolor[HTML]{63B163}} \color[HTML]{F1F1F1} 0.59 & {\cellcolor[HTML]{63B163}} \color[HTML]{F1F1F1} 0.59 \\
# \cline{1-6}
# \bfseries Mistral-7B & \bfseries - & {\cellcolor[HTML]{B9DBB9}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{B9DBB9}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{B9DBB9}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{B9DBB9}} \color[HTML]{000000} 0.47 \\
# \cline{1-6}
# \bfseries GFI & \bfseries - & {\cellcolor[HTML]{C8E2C8}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{C8E2C8}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{C8E2C8}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{C8E2C8}} \color[HTML]{000000} 0.45 \\
# \cline{1-6}
# \bfseries FKGL & \bfseries - & {\cellcolor[HTML]{DDECDD}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{DDECDD}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{DDECDD}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{DDECDD}} \color[HTML]{000000} 0.42 \\
# \cline{1-6}
# \bfseries ARI & \bfseries - & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.40 \\
# \cline{1-6}
# \bottomrule
# \end{tabular}
# \label{tab:LjL_metrics}
# \end{adjustbox}
# \end{table}
# <style type="text/css">
# #T_be5f2_row0_col0, #T_be5f2_row0_col1, #T_be5f2_row0_col2, #T_be5f2_row0_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
#   font-weight: bold;
#   color: #FF9999;
# }
# #T_be5f2_row1_col0, #T_be5f2_row1_col1, #T_be5f2_row1_col2, #T_be5f2_row1_col3 {
#   background-color: #0c860c;
#   color: #f1f1f1;
# }
# #T_be5f2_row2_col0, #T_be5f2_row2_col1, #T_be5f2_row2_col2, #T_be5f2_row2_col3, #T_be5f2_row3_col0, #T_be5f2_row3_col1, #T_be5f2_row3_col2, #T_be5f2_row3_col3 {
#   background-color: #209020;
#   color: #f1f1f1;
# }
# #T_be5f2_row4_col0, #T_be5f2_row4_col1, #T_be5f2_row4_col2, #T_be5f2_row4_col3 {
#   background-color: #249224;
#   color: #f1f1f1;
# }
# #T_be5f2_row5_col0, #T_be5f2_row5_col1, #T_be5f2_row5_col2, #T_be5f2_row5_col3 {
#   background-color: #3d9e3d;
#   color: #f1f1f1;
# }
# #T_be5f2_row6_col0, #T_be5f2_row6_col1, #T_be5f2_row6_col2, #T_be5f2_row6_col3 {
#   background-color: #6db66d;
#   color: #f1f1f1;
# }
# #T_be5f2_row7_col0, #T_be5f2_row7_col1, #T_be5f2_row7_col2, #T_be5f2_row7_col3, #T_be5f2_row8_col0, #T_be5f2_row8_col1, #T_be5f2_row8_col2, #T_be5f2_row8_col3 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_be5f2_row9_col0, #T_be5f2_row9_col1, #T_be5f2_row9_col2, #T_be5f2_row9_col3 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_be5f2_level0_row0, #T_be5f2_level1_row0, #T_be5f2_level1_row1, #T_be5f2_level0_row2, #T_be5f2_level1_row2, #T_be5f2_level0_row3, #T_be5f2_level1_row3, #T_be5f2_level0_row4, #T_be5f2_level1_row4, #T_be5f2_level0_row5, #T_be5f2_level1_row5, #T_be5f2_level1_row6, #T_be5f2_level0_row7, #T_be5f2_level1_row7, #T_be5f2_level0_row8, #T_be5f2_level1_row8, #T_be5f2_level0_row9, #T_be5f2_level1_row9 {
#   font-weight: bold;
# }
# #T_be5f2_level0_col0, #T_be5f2_level0_col1, #T_be5f2_level0_col2, #T_be5f2_level0_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_be5f2">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be5f2_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_be5f2_level0_col1" class="col_heading level0 col1" >f1 (micro)</th>
#       <th id="T_be5f2_level0_col2" class="col_heading level0 col2" >precision (micro)</th>
#       <th id="T_be5f2_level0_col3" class="col_heading level0 col3" >recall (micro)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >context</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be5f2_level0_row0" class="row_heading level0 row0" rowspan="2">GPT-3.5-turbo-1106</th>
#       <th id="T_be5f2_level1_row0" class="row_heading level1 row0" >\checkmark</th>
#       <td id="T_be5f2_row0_col0" class="data row0 col0" >0.90</td>
#       <td id="T_be5f2_row0_col1" class="data row0 col1" >0.90</td>
#       <td id="T_be5f2_row0_col2" class="data row0 col2" >0.90</td>
#       <td id="T_be5f2_row0_col3" class="data row0 col3" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_be5f2_level1_row1" class="row_heading level1 row1" >-</th>
#       <td id="T_be5f2_row1_col0" class="data row1 col0" >0.87</td>
#       <td id="T_be5f2_row1_col1" class="data row1 col1" >0.87</td>
#       <td id="T_be5f2_row1_col2" class="data row1 col2" >0.87</td>
#       <td id="T_be5f2_row1_col3" class="data row1 col3" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_be5f2_level0_row2" class="row_heading level0 row2" >Davinci-002</th>
#       <th id="T_be5f2_level1_row2" class="row_heading level1 row2" >-</th>
#       <td id="T_be5f2_row2_col0" class="data row2 col0" >0.82</td>
#       <td id="T_be5f2_row2_col1" class="data row2 col1" >0.82</td>
#       <td id="T_be5f2_row2_col2" class="data row2 col2" >0.82</td>
#       <td id="T_be5f2_row2_col3" class="data row2 col3" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_be5f2_level0_row3" class="row_heading level0 row3" >CamemBERT</th>
#       <th id="T_be5f2_level1_row3" class="row_heading level1 row3" >-</th>
#       <td id="T_be5f2_row3_col0" class="data row3 col0" >0.82</td>
#       <td id="T_be5f2_row3_col1" class="data row3 col1" >0.82</td>
#       <td id="T_be5f2_row3_col2" class="data row3 col2" >0.82</td>
#       <td id="T_be5f2_row3_col3" class="data row3 col3" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_be5f2_level0_row4" class="row_heading level0 row4" >Davinci-002</th>
#       <th id="T_be5f2_level1_row4" class="row_heading level1 row4" >\checkmark</th>
#       <td id="T_be5f2_row4_col0" class="data row4 col0" >0.81</td>
#       <td id="T_be5f2_row4_col1" class="data row4 col1" >0.81</td>
#       <td id="T_be5f2_row4_col2" class="data row4 col2" >0.81</td>
#       <td id="T_be5f2_row4_col3" class="data row4 col3" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_be5f2_level0_row5" class="row_heading level0 row5" rowspan="2">Mistral-7B</th>
#       <th id="T_be5f2_level1_row5" class="row_heading level1 row5" >\checkmark</th>
#       <td id="T_be5f2_row5_col0" class="data row5 col0" >0.75</td>
#       <td id="T_be5f2_row5_col1" class="data row5 col1" >0.75</td>
#       <td id="T_be5f2_row5_col2" class="data row5 col2" >0.75</td>
#       <td id="T_be5f2_row5_col3" class="data row5 col3" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_be5f2_level1_row6" class="row_heading level1 row6" >-</th>
#       <td id="T_be5f2_row6_col0" class="data row6 col0" >0.63</td>
#       <td id="T_be5f2_row6_col1" class="data row6 col1" >0.63</td>
#       <td id="T_be5f2_row6_col2" class="data row6 col2" >0.63</td>
#       <td id="T_be5f2_row6_col3" class="data row6 col3" >0.63</td>
#     </tr>
#     <tr>
#       <th id="T_be5f2_level0_row7" class="row_heading level0 row7" >ARI</th>
#       <th id="T_be5f2_level1_row7" class="row_heading level1 row7" >-</th>
#       <td id="T_be5f2_row7_col0" class="data row7 col0" >0.34</td>
#       <td id="T_be5f2_row7_col1" class="data row7 col1" >0.34</td>
#       <td id="T_be5f2_row7_col2" class="data row7 col2" >0.34</td>
#       <td id="T_be5f2_row7_col3" class="data row7 col3" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_be5f2_level0_row8" class="row_heading level0 row8" >FKGL</th>
#       <th id="T_be5f2_level1_row8" class="row_heading level1 row8" >-</th>
#       <td id="T_be5f2_row8_col0" class="data row8 col0" >0.34</td>
#       <td id="T_be5f2_row8_col1" class="data row8 col1" >0.34</td>
#       <td id="T_be5f2_row8_col2" class="data row8 col2" >0.34</td>
#       <td id="T_be5f2_row8_col3" class="data row8 col3" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_be5f2_level0_row9" class="row_heading level0 row9" >GFI</th>
#       <th id="T_be5f2_level1_row9" class="row_heading level1 row9" >-</th>
#       <td id="T_be5f2_row9_col0" class="data row9 col0" >0.32</td>
#       <td id="T_be5f2_row9_col1" class="data row9 col1" >0.32</td>
#       <td id="T_be5f2_row9_col2" class="data row9 col2" >0.32</td>
#       <td id="T_be5f2_row9_col3" class="data row9 col3" >0.32</td>
#     </tr>
#   </tbody>
# </table>
# \begin{table}[!h]
# \centering
# \caption{Metrics for the SentencesInternet dataset}
# \begin{adjustbox}{center}
# \begin{tabular}{llrrrr}
# \toprule
#  &  & \bfseries accuracy & \bfseries f1 (micro) & \bfseries precision (micro) & \bfseries recall (micro) \\
# model & context &  &  &  &  \\
# \midrule
# \multirow[c]{2}{*}{\bfseries GPT-3.5-turbo-1106} & \bfseries \checkmark & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.90 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.90 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.90 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.90 \\
# \bfseries  & \bfseries - & {\cellcolor[HTML]{0C860C}} \color[HTML]{F1F1F1} 0.87 & {\cellcolor[HTML]{0C860C}} \color[HTML]{F1F1F1} 0.87 & {\cellcolor[HTML]{0C860C}} \color[HTML]{F1F1F1} 0.87 & {\cellcolor[HTML]{0C860C}} \color[HTML]{F1F1F1} 0.87 \\
# \cline{1-6}
# \bfseries Davinci-002 & \bfseries - & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0.82 & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0.82 & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0.82 & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0.82 \\
# \cline{1-6}
# \bfseries CamemBERT & \bfseries - & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0.82 & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0.82 & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0.82 & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0.82 \\
# \cline{1-6}
# \bfseries Davinci-002 & \bfseries \checkmark & {\cellcolor[HTML]{249224}} \color[HTML]{F1F1F1} 0.81 & {\cellcolor[HTML]{249224}} \color[HTML]{F1F1F1} 0.81 & {\cellcolor[HTML]{249224}} \color[HTML]{F1F1F1} 0.81 & {\cellcolor[HTML]{249224}} \color[HTML]{F1F1F1} 0.81 \\
# \cline{1-6}
# \multirow[c]{2}{*}{\bfseries Mistral-7B} & \bfseries \checkmark & {\cellcolor[HTML]{3D9E3D}} \color[HTML]{F1F1F1} 0.75 & {\cellcolor[HTML]{3D9E3D}} \color[HTML]{F1F1F1} 0.75 & {\cellcolor[HTML]{3D9E3D}} \color[HTML]{F1F1F1} 0.75 & {\cellcolor[HTML]{3D9E3D}} \color[HTML]{F1F1F1} 0.75 \\
# \bfseries  & \bfseries - & {\cellcolor[HTML]{6DB66D}} \color[HTML]{F1F1F1} 0.63 & {\cellcolor[HTML]{6DB66D}} \color[HTML]{F1F1F1} 0.63 & {\cellcolor[HTML]{6DB66D}} \color[HTML]{F1F1F1} 0.63 & {\cellcolor[HTML]{6DB66D}} \color[HTML]{F1F1F1} 0.63 \\
# \cline{1-6}
# \bfseries ARI & \bfseries - & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0.34 \\
# \cline{1-6}
# \bfseries FKGL & \bfseries - & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0.34 \\
# \cline{1-6}
# \bfseries GFI & \bfseries - & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.32 \\
# \cline{1-6}
# \bottomrule
# \end{tabular}
# \label{tab:SentencesInternet_metrics}
# \end{adjustbox}
# \end{table}
# <style type="text/css">
# #T_d1369_row0_col0, #T_d1369_row0_col1, #T_d1369_row0_col2, #T_d1369_row0_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
#   font-weight: bold;
#   color: #FF9999;
# }
# #T_d1369_row1_col0, #T_d1369_row1_col1, #T_d1369_row1_col2, #T_d1369_row1_col3 {
#   background-color: #0d860d;
#   color: #f1f1f1;
# }
# #T_d1369_row2_col0, #T_d1369_row2_col1, #T_d1369_row2_col2, #T_d1369_row2_col3 {
#   background-color: #1a8d1a;
#   color: #f1f1f1;
# }
# #T_d1369_row3_col0, #T_d1369_row3_col1, #T_d1369_row3_col2, #T_d1369_row3_col3 {
#   background-color: #279327;
#   color: #f1f1f1;
# }
# #T_d1369_row4_col0, #T_d1369_row4_col1, #T_d1369_row4_col2, #T_d1369_row4_col3, #T_d1369_row5_col0, #T_d1369_row5_col1, #T_d1369_row5_col2, #T_d1369_row5_col3 {
#   background-color: #41a041;
#   color: #f1f1f1;
# }
# #T_d1369_row6_col0, #T_d1369_row6_col1, #T_d1369_row6_col2, #T_d1369_row6_col3, #T_d1369_row7_col0, #T_d1369_row7_col1, #T_d1369_row7_col2, #T_d1369_row7_col3 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_d1369_row8_col0, #T_d1369_row8_col1, #T_d1369_row8_col2, #T_d1369_row8_col3, #T_d1369_row9_col0, #T_d1369_row9_col1, #T_d1369_row9_col2, #T_d1369_row9_col3 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_d1369_level0_row0, #T_d1369_level1_row0, #T_d1369_level0_row1, #T_d1369_level1_row1, #T_d1369_level0_row2, #T_d1369_level1_row2, #T_d1369_level1_row3, #T_d1369_level0_row4, #T_d1369_level1_row4, #T_d1369_level1_row5, #T_d1369_level0_row6, #T_d1369_level1_row6, #T_d1369_level0_row7, #T_d1369_level1_row7, #T_d1369_level0_row8, #T_d1369_level1_row8, #T_d1369_level0_row9, #T_d1369_level1_row9 {
#   font-weight: bold;
# }
# #T_d1369_level0_col0, #T_d1369_level0_col1, #T_d1369_level0_col2, #T_d1369_level0_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d1369">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1369_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_d1369_level0_col1" class="col_heading level0 col1" >f1 (micro)</th>
#       <th id="T_d1369_level0_col2" class="col_heading level0 col2" >precision (micro)</th>
#       <th id="T_d1369_level0_col3" class="col_heading level0 col3" >recall (micro)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >context</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1369_level0_row0" class="row_heading level0 row0" >CamemBERT</th>
#       <th id="T_d1369_level1_row0" class="row_heading level1 row0" >-</th>
#       <td id="T_d1369_row0_col0" class="data row0 col0" >0.52</td>
#       <td id="T_d1369_row0_col1" class="data row0 col1" >0.52</td>
#       <td id="T_d1369_row0_col2" class="data row0 col2" >0.52</td>
#       <td id="T_d1369_row0_col3" class="data row0 col3" >0.52</td>
#     </tr>
#     <tr>
#       <th id="T_d1369_level0_row1" class="row_heading level0 row1" >Mistral-7B</th>
#       <th id="T_d1369_level1_row1" class="row_heading level1 row1" >\checkmark</th>
#       <td id="T_d1369_row1_col0" class="data row1 col0" >0.51</td>
#       <td id="T_d1369_row1_col1" class="data row1 col1" >0.51</td>
#       <td id="T_d1369_row1_col2" class="data row1 col2" >0.51</td>
#       <td id="T_d1369_row1_col3" class="data row1 col3" >0.51</td>
#     </tr>
#     <tr>
#       <th id="T_d1369_level0_row2" class="row_heading level0 row2" rowspan="2">GPT-3.5-turbo-1106</th>
#       <th id="T_d1369_level1_row2" class="row_heading level1 row2" >\checkmark</th>
#       <td id="T_d1369_row2_col0" class="data row2 col0" >0.50</td>
#       <td id="T_d1369_row2_col1" class="data row2 col1" >0.50</td>
#       <td id="T_d1369_row2_col2" class="data row2 col2" >0.50</td>
#       <td id="T_d1369_row2_col3" class="data row2 col3" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_d1369_level1_row3" class="row_heading level1 row3" >-</th>
#       <td id="T_d1369_row3_col0" class="data row3 col0" >0.49</td>
#       <td id="T_d1369_row3_col1" class="data row3 col1" >0.49</td>
#       <td id="T_d1369_row3_col2" class="data row3 col2" >0.49</td>
#       <td id="T_d1369_row3_col3" class="data row3 col3" >0.49</td>
#     </tr>
#     <tr>
#       <th id="T_d1369_level0_row4" class="row_heading level0 row4" rowspan="2">Davinci-002</th>
#       <th id="T_d1369_level1_row4" class="row_heading level1 row4" >\checkmark</th>
#       <td id="T_d1369_row4_col0" class="data row4 col0" >0.47</td>
#       <td id="T_d1369_row4_col1" class="data row4 col1" >0.47</td>
#       <td id="T_d1369_row4_col2" class="data row4 col2" >0.47</td>
#       <td id="T_d1369_row4_col3" class="data row4 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_d1369_level1_row5" class="row_heading level1 row5" >-</th>
#       <td id="T_d1369_row5_col0" class="data row5 col0" >0.47</td>
#       <td id="T_d1369_row5_col1" class="data row5 col1" >0.47</td>
#       <td id="T_d1369_row5_col2" class="data row5 col2" >0.47</td>
#       <td id="T_d1369_row5_col3" class="data row5 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_d1369_level0_row6" class="row_heading level0 row6" >Mistral-7B</th>
#       <th id="T_d1369_level1_row6" class="row_heading level1 row6" >-</th>
#       <td id="T_d1369_row6_col0" class="data row6 col0" >0.35</td>
#       <td id="T_d1369_row6_col1" class="data row6 col1" >0.35</td>
#       <td id="T_d1369_row6_col2" class="data row6 col2" >0.35</td>
#       <td id="T_d1369_row6_col3" class="data row6 col3" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_d1369_level0_row7" class="row_heading level0 row7" >FKGL</th>
#       <th id="T_d1369_level1_row7" class="row_heading level1 row7" >-</th>
#       <td id="T_d1369_row7_col0" class="data row7 col0" >0.35</td>
#       <td id="T_d1369_row7_col1" class="data row7 col1" >0.35</td>
#       <td id="T_d1369_row7_col2" class="data row7 col2" >0.35</td>
#       <td id="T_d1369_row7_col3" class="data row7 col3" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_d1369_level0_row8" class="row_heading level0 row8" >ARI</th>
#       <th id="T_d1369_level1_row8" class="row_heading level1 row8" >-</th>
#       <td id="T_d1369_row8_col0" class="data row8 col0" >0.34</td>
#       <td id="T_d1369_row8_col1" class="data row8 col1" >0.34</td>
#       <td id="T_d1369_row8_col2" class="data row8 col2" >0.34</td>
#       <td id="T_d1369_row8_col3" class="data row8 col3" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_d1369_level0_row9" class="row_heading level0 row9" >GFI</th>
#       <th id="T_d1369_level1_row9" class="row_heading level1 row9" >-</th>
#       <td id="T_d1369_row9_col0" class="data row9 col0" >0.34</td>
#       <td id="T_d1369_row9_col1" class="data row9 col1" >0.34</td>
#       <td id="T_d1369_row9_col2" class="data row9 col2" >0.34</td>
#       <td id="T_d1369_row9_col3" class="data row9 col3" >0.34</td>
#     </tr>
#   </tbody>
# </table>
# \begin{table}[!h]
# \centering
# \caption{Metrics for the SentencesBooks dataset}
# \begin{adjustbox}{center}
# \begin{tabular}{llrrrr}
# \toprule
#  &  & \bfseries accuracy & \bfseries f1 (micro) & \bfseries precision (micro) & \bfseries recall (micro) \\
# model & context &  &  &  &  \\
# \midrule
# \bfseries CamemBERT & \bfseries - & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.52 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.52 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.52 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.52 \\
# \cline{1-6}
# \bfseries Mistral-7B & \bfseries \checkmark & {\cellcolor[HTML]{0D860D}} \color[HTML]{F1F1F1} 0.51 & {\cellcolor[HTML]{0D860D}} \color[HTML]{F1F1F1} 0.51 & {\cellcolor[HTML]{0D860D}} \color[HTML]{F1F1F1} 0.51 & {\cellcolor[HTML]{0D860D}} \color[HTML]{F1F1F1} 0.51 \\
# \cline{1-6}
# \multirow[c]{2}{*}{\bfseries GPT-3.5-turbo-1106} & \bfseries \checkmark & {\cellcolor[HTML]{1A8D1A}} \color[HTML]{F1F1F1} 0.50 & {\cellcolor[HTML]{1A8D1A}} \color[HTML]{F1F1F1} 0.50 & {\cellcolor[HTML]{1A8D1A}} \color[HTML]{F1F1F1} 0.50 & {\cellcolor[HTML]{1A8D1A}} \color[HTML]{F1F1F1} 0.50 \\
# \bfseries  & \bfseries - & {\cellcolor[HTML]{279327}} \color[HTML]{F1F1F1} 0.49 & {\cellcolor[HTML]{279327}} \color[HTML]{F1F1F1} 0.49 & {\cellcolor[HTML]{279327}} \color[HTML]{F1F1F1} 0.49 & {\cellcolor[HTML]{279327}} \color[HTML]{F1F1F1} 0.49 \\
# \cline{1-6}
# \multirow[c]{2}{*}{\bfseries Davinci-002} & \bfseries \checkmark & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0.47 & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0.47 & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0.47 & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0.47 \\
# \bfseries  & \bfseries - & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0.47 & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0.47 & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0.47 & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0.47 \\
# \cline{1-6}
# \bfseries Mistral-7B & \bfseries - & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0.35 & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0.35 & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0.35 & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0.35 \\
# \cline{1-6}
# \bfseries FKGL & \bfseries - & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0.35 & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0.35 & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0.35 & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0.35 \\
# \cline{1-6}
# \bfseries ARI & \bfseries - & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.34 \\
# \cline{1-6}
# \bfseries GFI & \bfseries - & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.34 \\
# \cline{1-6}
# \bottomrule
# \end{tabular}
# \label{tab:SentencesBooks_metrics}
# \end{adjustbox}
# \end{table}

# %%
# Mute pandas warning
import warnings
import seaborn as sns

warnings.simplefilter(action="ignore", category=FutureWarning)


# Bold best results
def highlight_best(x):
    # Create empty dataframe
    df = pd.DataFrame("", index=x.index, columns=x.columns)

    # Bold max of accuracy	f1 (micro)	precision (micro)	recall (micro)
    for metric in df.columns:
        df[metric].loc[x[metric].idxmax()] += "font-weight: bold; color: #FF9999;"

    return df

df = datasets_metrics_df.copy()

# Styled dataframe
styled_df = (
    df.style.background_gradient(cmap=sns.light_palette("green", as_cmap=True))
    .apply(highlight_best, axis=None)
    .applymap_index(lambda v: "font-weight: bold;", axis="columns")
    .applymap_index(lambda v: "font-weight: bold;", axis="rows")
    .format(decimal=".", thousands=",", precision=2)
)
display(styled_df)
path = os.path.join(pwd, "figures", "difficulty_estimation", f"difficulty_estimation_metrics.tex")
if not os.path.exists(os.path.dirname(path)):
    os.makedirs(os.path.dirname(path))
latex = styled_df.to_latex(
    caption=(f"Difficulty estimation metrics for all datasets"),
    clines="skip-last;data",
    convert_css=True,
    position_float="centering",
    multicol_align="|c|",
    hrules=True,
)

# Add \begin{adjustbox}{center}
latex = latex.replace(
    "\\begin{tabular}", "\\begin{adjustbox}{center}\n\\begin{tabular}"
).replace(
    "\\end{tabular}",
    f"\\end{{tabular}}\n\\label{{tab:difficulty_estimation_metrics}}\n\\end{{adjustbox}}",
)

# Force position of table
latex = latex.replace("\\begin{table}", "\\begin{table}[!h]")

print(latex)
# Out:
# <style type="text/css">
# #T_f3af0_row0_col0 {
#   background-color: #068306;
#   color: #f1f1f1;
# }
# #T_f3af0_row0_col1, #T_f3af0_row1_col0, #T_f3af0_row2_col2 {
#   background-color: #008000;
#   color: #f1f1f1;
#   font-weight: bold;
#   color: #FF9999;
# }
# #T_f3af0_row0_col2 {
#   background-color: #1a8d1a;
#   color: #f1f1f1;
# }
# #T_f3af0_row1_col1 {
#   background-color: #0c860c;
#   color: #f1f1f1;
# }
# #T_f3af0_row1_col2 {
#   background-color: #279327;
#   color: #f1f1f1;
# }
# #T_f3af0_row2_col0 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_f3af0_row2_col1, #T_f3af0_row4_col1 {
#   background-color: #209020;
#   color: #f1f1f1;
# }
# #T_f3af0_row3_col0 {
#   background-color: #3f9f3f;
#   color: #f1f1f1;
# }
# #T_f3af0_row3_col1 {
#   background-color: #3d9e3d;
#   color: #f1f1f1;
# }
# #T_f3af0_row3_col2 {
#   background-color: #0d860d;
#   color: #f1f1f1;
# }
# #T_f3af0_row4_col0 {
#   background-color: #63b163;
#   color: #f1f1f1;
# }
# #T_f3af0_row4_col2, #T_f3af0_row5_col2 {
#   background-color: #41a041;
#   color: #f1f1f1;
# }
# #T_f3af0_row5_col0 {
#   background-color: #56aa56;
#   color: #f1f1f1;
# }
# #T_f3af0_row5_col1 {
#   background-color: #249224;
#   color: #f1f1f1;
# }
# #T_f3af0_row6_col0 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_f3af0_row6_col1 {
#   background-color: #6db66d;
#   color: #f1f1f1;
# }
# #T_f3af0_row6_col2, #T_f3af0_row7_col2 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_f3af0_row7_col0 {
#   background-color: #ddecdd;
#   color: #000000;
# }
# #T_f3af0_row7_col1, #T_f3af0_row9_col1 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_f3af0_row8_col0 {
#   background-color: #c8e2c8;
#   color: #000000;
# }
# #T_f3af0_row8_col1, #T_f3af0_row8_col2, #T_f3af0_row9_col0, #T_f3af0_row9_col2 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_f3af0_level0_row0, #T_f3af0_level1_row0, #T_f3af0_level1_row1, #T_f3af0_level0_row2, #T_f3af0_level1_row2, #T_f3af0_level0_row3, #T_f3af0_level1_row3, #T_f3af0_level0_row4, #T_f3af0_level1_row4, #T_f3af0_level1_row5, #T_f3af0_level0_row6, #T_f3af0_level1_row6, #T_f3af0_level0_row7, #T_f3af0_level1_row7, #T_f3af0_level0_row8, #T_f3af0_level1_row8, #T_f3af0_level0_row9, #T_f3af0_level1_row9 {
#   font-weight: bold;
# }
# #T_f3af0_level0_col0, #T_f3af0_level0_col1, #T_f3af0_level0_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f3af0">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3af0_level0_col0" class="col_heading level0 col0" >LjL</th>
#       <th id="T_f3af0_level0_col1" class="col_heading level0 col1" >SentencesInternet</th>
#       <th id="T_f3af0_level0_col2" class="col_heading level0 col2" >SentencesBooks</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >context</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3af0_level0_row0" class="row_heading level0 row0" rowspan="2">GPT-3.5-turbo-1106</th>
#       <th id="T_f3af0_level1_row0" class="row_heading level1 row0" >\checkmark</th>
#       <td id="T_f3af0_row0_col0" class="data row0 col0" >0.72</td>
#       <td id="T_f3af0_row0_col1" class="data row0 col1" >0.90</td>
#       <td id="T_f3af0_row0_col2" class="data row0 col2" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_f3af0_level1_row1" class="row_heading level1 row1" >-</th>
#       <td id="T_f3af0_row1_col0" class="data row1 col0" >0.73</td>
#       <td id="T_f3af0_row1_col1" class="data row1 col1" >0.87</td>
#       <td id="T_f3af0_row1_col2" class="data row1 col2" >0.49</td>
#     </tr>
#     <tr>
#       <th id="T_f3af0_level0_row2" class="row_heading level0 row2" >CamemBERT</th>
#       <th id="T_f3af0_level1_row2" class="row_heading level1 row2" >-</th>
#       <td id="T_f3af0_row2_col0" class="data row2 col0" >0.62</td>
#       <td id="T_f3af0_row2_col1" class="data row2 col1" >0.82</td>
#       <td id="T_f3af0_row2_col2" class="data row2 col2" >0.52</td>
#     </tr>
#     <tr>
#       <th id="T_f3af0_level0_row3" class="row_heading level0 row3" >Mistral-7B</th>
#       <th id="T_f3af0_level1_row3" class="row_heading level1 row3" >\checkmark</th>
#       <td id="T_f3af0_row3_col0" class="data row3 col0" >0.64</td>
#       <td id="T_f3af0_row3_col1" class="data row3 col1" >0.75</td>
#       <td id="T_f3af0_row3_col2" class="data row3 col2" >0.51</td>
#     </tr>
#     <tr>
#       <th id="T_f3af0_level0_row4" class="row_heading level0 row4" rowspan="2">Davinci-002</th>
#       <th id="T_f3af0_level1_row4" class="row_heading level1 row4" >-</th>
#       <td id="T_f3af0_row4_col0" class="data row4 col0" >0.59</td>
#       <td id="T_f3af0_row4_col1" class="data row4 col1" >0.82</td>
#       <td id="T_f3af0_row4_col2" class="data row4 col2" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_f3af0_level1_row5" class="row_heading level1 row5" >\checkmark</th>
#       <td id="T_f3af0_row5_col0" class="data row5 col0" >0.61</td>
#       <td id="T_f3af0_row5_col1" class="data row5 col1" >0.81</td>
#       <td id="T_f3af0_row5_col2" class="data row5 col2" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_f3af0_level0_row6" class="row_heading level0 row6" >Mistral-7B</th>
#       <th id="T_f3af0_level1_row6" class="row_heading level1 row6" >-</th>
#       <td id="T_f3af0_row6_col0" class="data row6 col0" >0.47</td>
#       <td id="T_f3af0_row6_col1" class="data row6 col1" >0.63</td>
#       <td id="T_f3af0_row6_col2" class="data row6 col2" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_f3af0_level0_row7" class="row_heading level0 row7" >FKGL</th>
#       <th id="T_f3af0_level1_row7" class="row_heading level1 row7" >-</th>
#       <td id="T_f3af0_row7_col0" class="data row7 col0" >0.42</td>
#       <td id="T_f3af0_row7_col1" class="data row7 col1" >0.34</td>
#       <td id="T_f3af0_row7_col2" class="data row7 col2" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_f3af0_level0_row8" class="row_heading level0 row8" >GFI</th>
#       <th id="T_f3af0_level1_row8" class="row_heading level1 row8" >-</th>
#       <td id="T_f3af0_row8_col0" class="data row8 col0" >0.45</td>
#       <td id="T_f3af0_row8_col1" class="data row8 col1" >0.32</td>
#       <td id="T_f3af0_row8_col2" class="data row8 col2" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_f3af0_level0_row9" class="row_heading level0 row9" >ARI</th>
#       <th id="T_f3af0_level1_row9" class="row_heading level1 row9" >-</th>
#       <td id="T_f3af0_row9_col0" class="data row9 col0" >0.40</td>
#       <td id="T_f3af0_row9_col1" class="data row9 col1" >0.34</td>
#       <td id="T_f3af0_row9_col2" class="data row9 col2" >0.34</td>
#     </tr>
#   </tbody>
# </table>
# \begin{table}[!h]
# \centering
# \caption{Difficulty estimation metrics for all datasets}
# \begin{adjustbox}{center}
# \begin{tabular}{llrrr}
# \toprule
#  &  & \bfseries LjL & \bfseries SentencesInternet & \bfseries SentencesBooks \\
# model & context &  &  &  \\
# \midrule
# \multirow[c]{2}{*}{\bfseries GPT-3.5-turbo-1106} & \bfseries \checkmark & {\cellcolor[HTML]{068306}} \color[HTML]{F1F1F1} 0.72 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.90 & {\cellcolor[HTML]{1A8D1A}} \color[HTML]{F1F1F1} 0.50 \\
# \bfseries  & \bfseries - & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.73 & {\cellcolor[HTML]{0C860C}} \color[HTML]{F1F1F1} 0.87 & {\cellcolor[HTML]{279327}} \color[HTML]{F1F1F1} 0.49 \\
# \cline{1-5}
# \bfseries CamemBERT & \bfseries - & {\cellcolor[HTML]{4EA64E}} \color[HTML]{F1F1F1} 0.62 & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0.82 & {\cellcolor[HTML]{008000}} \color[HTML]{F1F1F1} \bfseries \color[HTML]{FF9999} 0.52 \\
# \cline{1-5}
# \bfseries Mistral-7B & \bfseries \checkmark & {\cellcolor[HTML]{3F9F3F}} \color[HTML]{F1F1F1} 0.64 & {\cellcolor[HTML]{3D9E3D}} \color[HTML]{F1F1F1} 0.75 & {\cellcolor[HTML]{0D860D}} \color[HTML]{F1F1F1} 0.51 \\
# \cline{1-5}
# \multirow[c]{2}{*}{\bfseries Davinci-002} & \bfseries - & {\cellcolor[HTML]{63B163}} \color[HTML]{F1F1F1} 0.59 & {\cellcolor[HTML]{209020}} \color[HTML]{F1F1F1} 0.82 & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0.47 \\
# \bfseries  & \bfseries \checkmark & {\cellcolor[HTML]{56AA56}} \color[HTML]{F1F1F1} 0.61 & {\cellcolor[HTML]{249224}} \color[HTML]{F1F1F1} 0.81 & {\cellcolor[HTML]{41A041}} \color[HTML]{F1F1F1} 0.47 \\
# \cline{1-5}
# \bfseries Mistral-7B & \bfseries - & {\cellcolor[HTML]{B9DBB9}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{6DB66D}} \color[HTML]{F1F1F1} 0.63 & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0.35 \\
# \cline{1-5}
# \bfseries FKGL & \bfseries - & {\cellcolor[HTML]{DDECDD}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{DEEDDE}} \color[HTML]{000000} 0.35 \\
# \cline{1-5}
# \bfseries GFI & \bfseries - & {\cellcolor[HTML]{C8E2C8}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.34 \\
# \cline{1-5}
# \bfseries ARI & \bfseries - & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{E3EFE3}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{EBF3EB}} \color[HTML]{000000} 0.34 \\
# \cline{1-5}
# \bottomrule
# \end{tabular}
# \label{tab:difficulty_estimation_metrics}
# \end{adjustbox}
# \end{table}

# %% [markdown]
# ### Figures

# %%
from matplotlib import pyplot as plt
import matplotlib

matplotlib.use("pgf")
matplotlib.rcParams.update(
    {
        "pgf.texsystem": "pdflatex",
        "font.family": "serif",
        "text.usetex": True,
        "pgf.rcfonts": False,
        "font.size": 10,
    }
)

# Bar plot of accuracy one bar per model and context on each dataset
df = concatenated_metrics.copy()
# Create model + context column
df["model + context"] = df["model"] + df["context"].replace("-", "").replace(
    "\checkmark", " + CECRL"
)
plt.figure()
barplot = sns.barplot(
    x="dataset",
    y="accuracy",
    hue="model + context",
    data=df,
    palette=sns.color_palette(
        [
            "#6baed6",
            "#3182bd",
            "#e6550d",
            "yellow",
            "#756bb1",
            "#9e9ac8",
            "#fd8d3c",
            "#31a354",
            "#74c476",
            "#a1d99b",
        ]
    ),
    ci=None,
)

# Itérer sur les barres du graphique et ajouter le texte à l'intérieur de chaque barre.
for p in barplot.patches:
    if p.get_height() > 0.0:
        barplot.annotate(
            "{}%".format(int(p.get_height() * 100)),  # Format pour la hauteur/accuracy
            (p.get_x() + p.get_width() / 2.0, p.get_height()),
            ha="center",
            va="center",
            xytext=(0, 5),
            textcoords="offset points",
            fontsize=5,
        )

plt.legend(loc="upper right", fontsize=7)
plt.xlabel("Dataset", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
sns.despine()  # Retrait des bordures indésirables
plt.tight_layout()
# Set size inches
plt.gcf().set_size_inches(8, h=8 / 1.618)
# Reduce font size
plt.rcParams.update({"font.size": 6})

# Export to latex
path = os.path.join(pwd, "figures", "difficulty_estimation", "accuracy.pgf")
if not os.path.exists(os.path.dirname(path)):
    os.makedirs(os.path.dirname(path))
plt.savefig(path)

# Display latex
with open(path, "r") as file:
    latex = file.read()
print(latex)
# Out:
# %% Creator: Matplotlib, PGF backend
# %%
# %% To include the figure in your LaTeX document, write
# %%   \input{<filename>.pgf}
# %%
# %% Make sure the required packages are loaded in your preamble
# %%   \usepackage{pgf}
# %%
# %% Also ensure that all the required font packages are loaded; for instance,
# %% the lmodern package is sometimes necessary when using math font.
# %%   \usepackage{lmodern}
# %%
# %% Figures using additional raster images can only be included by \input if
# %% they are in the same directory as the main LaTeX file. For loading figures
# %% from other directories you can use the `import` package
# %%   \usepackage{import}
# %%
# %% and then include the figures with
# %%   \import{<path to file>}{<filename>.pgf}
# %%
# %% Matplotlib used the following preamble
# %%   \def\mathdefault#1{#1}
# %%   \everymath=\expandafter{\the\everymath\displaystyle}
# %%
# %%   \makeatletter\@ifpackageloaded{underscore}{}{\usepackage[strings]{underscore}}\makeatother
# %%
# \begingroup%
# \makeatletter%
# \begin{pgfpicture}%
# \pgfpathrectangle{\pgfpointorigin}{\pgfqpoint{8.000000in}{4.944376in}}%
# \pgfusepath{use as bounding box, clip}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{8.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{8.000000in}{4.944376in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{4.944376in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.785494in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.812500in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.812500in}{4.789864in}}%
# \pgfpathlineto{\pgfqpoint{0.785494in}{4.789864in}}%
# \pgfpathlineto{\pgfqpoint{0.785494in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.472059,0.669118,0.786765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.019727in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.207114in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.207114in}{3.834717in}}%
# \pgfpathlineto{\pgfqpoint{1.019727in}{3.834717in}}%
# \pgfpathlineto{\pgfqpoint{1.019727in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.472059,0.669118,0.786765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.362063in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.549450in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.549450in}{4.456673in}}%
# \pgfpathlineto{\pgfqpoint{3.362063in}{4.456673in}}%
# \pgfpathlineto{\pgfqpoint{3.362063in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.472059,0.669118,0.786765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.704398in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.891785in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.891785in}{2.768506in}}%
# \pgfpathlineto{\pgfqpoint{5.704398in}{2.768506in}}%
# \pgfpathlineto{\pgfqpoint{5.704398in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.260784,0.499020,0.672549}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.207114in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.394501in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.394501in}{3.790291in}}%
# \pgfpathlineto{\pgfqpoint{1.207114in}{3.790291in}}%
# \pgfpathlineto{\pgfqpoint{1.207114in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.260784,0.499020,0.672549}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.549450in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.736836in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.736836in}{4.589949in}}%
# \pgfpathlineto{\pgfqpoint{3.549450in}{4.589949in}}%
# \pgfpathlineto{\pgfqpoint{3.549450in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.260784,0.499020,0.672549}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.891785in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.079172in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.079172in}{2.812931in}}%
# \pgfpathlineto{\pgfqpoint{5.891785in}{2.812931in}}%
# \pgfpathlineto{\pgfqpoint{5.891785in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.795588,0.369118,0.157353}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.394501in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.581888in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.581888in}{3.434888in}}%
# \pgfpathlineto{\pgfqpoint{1.394501in}{3.434888in}}%
# \pgfpathlineto{\pgfqpoint{1.394501in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.795588,0.369118,0.157353}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.736836in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.924223in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{3.924223in}{3.923568in}}%
# \pgfpathlineto{\pgfqpoint{3.736836in}{3.923568in}}%
# \pgfpathlineto{\pgfqpoint{3.736836in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.795588,0.369118,0.157353}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.079172in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.266559in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.266559in}{2.857357in}}%
# \pgfpathlineto{\pgfqpoint{6.079172in}{2.857357in}}%
# \pgfpathlineto{\pgfqpoint{6.079172in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.875000,0.875000,0.125000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.581888in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.769275in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.769275in}{3.346037in}}%
# \pgfpathlineto{\pgfqpoint{1.581888in}{3.346037in}}%
# \pgfpathlineto{\pgfqpoint{1.581888in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.875000,0.875000,0.125000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.924223in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.111610in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.111610in}{4.234546in}}%
# \pgfpathlineto{\pgfqpoint{3.924223in}{4.234546in}}%
# \pgfpathlineto{\pgfqpoint{3.924223in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.875000,0.875000,0.125000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.266559in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.453945in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.453945in}{2.901782in}}%
# \pgfpathlineto{\pgfqpoint{6.266559in}{2.901782in}}%
# \pgfpathlineto{\pgfqpoint{6.266559in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.483333,0.453922,0.659804}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.769275in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{3.301611in}}%
# \pgfpathlineto{\pgfqpoint{1.769275in}{3.301611in}}%
# \pgfpathlineto{\pgfqpoint{1.769275in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.483333,0.453922,0.659804}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.111610in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.298997in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.298997in}{4.190120in}}%
# \pgfpathlineto{\pgfqpoint{4.111610in}{4.190120in}}%
# \pgfpathlineto{\pgfqpoint{4.111610in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.483333,0.453922,0.659804}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.453945in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.641332in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.641332in}{2.679655in}}%
# \pgfpathlineto{\pgfqpoint{6.453945in}{2.679655in}}%
# \pgfpathlineto{\pgfqpoint{6.453945in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.638235,0.626471,0.761765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.144048in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.144048in}{3.212760in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{3.212760in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.638235,0.626471,0.761765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.298997in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.486384in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.486384in}{4.234546in}}%
# \pgfpathlineto{\pgfqpoint{4.298997in}{4.234546in}}%
# \pgfpathlineto{\pgfqpoint{4.298997in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.638235,0.626471,0.761765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.641332in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.828719in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{6.828719in}{2.679655in}}%
# \pgfpathlineto{\pgfqpoint{6.641332in}{2.679655in}}%
# \pgfpathlineto{\pgfqpoint{6.641332in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.897549,0.568137,0.329902}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.144048in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.331435in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.331435in}{2.679655in}}%
# \pgfpathlineto{\pgfqpoint{2.144048in}{2.679655in}}%
# \pgfpathlineto{\pgfqpoint{2.144048in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.897549,0.568137,0.329902}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.486384in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.673771in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.673771in}{3.390462in}}%
# \pgfpathlineto{\pgfqpoint{4.486384in}{3.390462in}}%
# \pgfpathlineto{\pgfqpoint{4.486384in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.897549,0.568137,0.329902}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.828719in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.016106in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.016106in}{2.146549in}}%
# \pgfpathlineto{\pgfqpoint{6.828719in}{2.146549in}}%
# \pgfpathlineto{\pgfqpoint{6.828719in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.248039,0.583333,0.350980}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.331435in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.518822in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.518822in}{2.590804in}}%
# \pgfpathlineto{\pgfqpoint{2.331435in}{2.590804in}}%
# \pgfpathlineto{\pgfqpoint{2.331435in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.248039,0.583333,0.350980}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.673771in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.861157in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{4.861157in}{2.013273in}}%
# \pgfpathlineto{\pgfqpoint{4.673771in}{2.013273in}}%
# \pgfpathlineto{\pgfqpoint{4.673771in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.248039,0.583333,0.350980}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.016106in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.203493in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.203493in}{2.102124in}}%
# \pgfpathlineto{\pgfqpoint{7.016106in}{2.102124in}}%
# \pgfpathlineto{\pgfqpoint{7.016106in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.494118,0.729412,0.500000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.518822in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.706209in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.706209in}{2.368677in}}%
# \pgfpathlineto{\pgfqpoint{2.518822in}{2.368677in}}%
# \pgfpathlineto{\pgfqpoint{2.518822in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.494118,0.729412,0.500000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.861157in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.048544in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.048544in}{2.102124in}}%
# \pgfpathlineto{\pgfqpoint{4.861157in}{2.102124in}}%
# \pgfpathlineto{\pgfqpoint{4.861157in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.494118,0.729412,0.500000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.203493in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.390880in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.390880in}{2.102124in}}%
# \pgfpathlineto{\pgfqpoint{7.203493in}{2.102124in}}%
# \pgfpathlineto{\pgfqpoint{7.203493in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.655882,0.820588,0.638235}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.706209in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.893596in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{2.893596in}{2.457528in}}%
# \pgfpathlineto{\pgfqpoint{2.706209in}{2.457528in}}%
# \pgfpathlineto{\pgfqpoint{2.706209in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.655882,0.820588,0.638235}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.048544in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.235931in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{5.235931in}{2.102124in}}%
# \pgfpathlineto{\pgfqpoint{5.048544in}{2.102124in}}%
# \pgfpathlineto{\pgfqpoint{5.048544in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.655882,0.820588,0.638235}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.390880in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.578266in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.578266in}{2.146549in}}%
# \pgfpathlineto{\pgfqpoint{7.390880in}{2.146549in}}%
# \pgfpathlineto{\pgfqpoint{7.390880in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.472059,0.669118,0.786765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.260784,0.499020,0.672549}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.795588,0.369118,0.157353}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.875000,0.875000,0.125000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.483333,0.453922,0.659804}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.638235,0.626471,0.761765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.897549,0.568137,0.329902}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.248039,0.583333,0.350980}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.494118,0.729412,0.500000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.785494in}{0.591658in}}{\pgfqpoint{7.027006in}{4.198206in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.655882,0.820588,0.638235}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{1.956661in}{0.591658in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{1.956661in}{0.591658in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.956661in,y=0.494436in,,top]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}LjL}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{4.298997in}{0.591658in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.298997in,y=0.494436in,,top]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}SentencesInternet}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{6.641332in}{0.591658in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.641332in,y=0.494436in,,top]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}SentencesBooks}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.298997in,y=0.315424in,,top]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Dataset}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.785494in}{0.591658in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.510802in, y=0.543433in, left, base]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}$\mathdefault{0.0}$}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.785494in}{1.480168in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.510802in, y=1.431942in, left, base]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}$\mathdefault{0.2}$}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.785494in}{2.368677in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.510802in, y=2.320451in, left, base]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}$\mathdefault{0.4}$}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.785494in}{3.257186in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.510802in, y=3.208960in, left, base]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}$\mathdefault{0.6}$}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.785494in}{4.145695in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.510802in, y=4.097470in, left, base]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}$\mathdefault{0.8}$}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.455246in,y=2.690761in,,bottom,rotate=90.000000]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Accuracy}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetrectcap%
# \pgfsetmiterjoin%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.785494in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{0.785494in}{4.789864in}}%
# \pgfusepath{stroke}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetrectcap%
# \pgfsetmiterjoin%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.785494in}{0.591658in}}%
# \pgfpathlineto{\pgfqpoint{7.812500in}{0.591658in}}%
# \pgfusepath{stroke}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.113421in,y=3.904161in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}73%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.455756in,y=4.526118in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}87%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=5.798092in,y=2.837950in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}49%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.300808in,y=3.859736in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}72%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.643143in,y=4.659394in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}90%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=5.985478in,y=2.882376in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}50%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.488194in,y=3.504332in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}64%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.830530in,y=3.993012in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}75%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.172865in,y=2.926801in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}51%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.675581in,y=3.415481in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}62%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.017917in,y=4.303990in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}82%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.360252in,y=2.971227in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}52%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.862968in,y=3.371056in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}61%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.205303in,y=4.259565in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}81%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.547639in,y=2.749099in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}47%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.050355in,y=3.282205in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}59%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.392690in,y=4.303990in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}82%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.735026in,y=2.749099in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}47%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.237742in,y=2.749099in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}47%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.580077in,y=3.459907in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}63%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.922413in,y=2.215994in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}35%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.425129in,y=2.660248in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}45%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.767464in,y=2.082717in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}32%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=7.109799in,y=2.171568in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}34%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.612515in,y=2.438121in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}40%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.954851in,y=2.171568in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}34%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=7.297186in,y=2.171568in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}34%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.799902in,y=2.526972in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}42%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=5.142238in,y=2.171568in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}34%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=7.484573in,y=2.215994in,,]{\color{textcolor}{\rmfamily\fontsize{5.000000}{6.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}35%}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetfillopacity{0.800000}%
# \pgfsetlinewidth{1.003750pt}%
# \definecolor{currentstroke}{rgb}{0.800000,0.800000,0.800000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.800000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.907092in}{3.356378in}}%
# \pgfpathlineto{\pgfqpoint{7.744444in}{3.356378in}}%
# \pgfpathquadraticcurveto{\pgfqpoint{7.763889in}{3.356378in}}{\pgfqpoint{7.763889in}{3.375822in}}%
# \pgfpathlineto{\pgfqpoint{7.763889in}{4.721808in}}%
# \pgfpathquadraticcurveto{\pgfqpoint{7.763889in}{4.741253in}}{\pgfqpoint{7.744444in}{4.741253in}}%
# \pgfpathlineto{\pgfqpoint{5.907092in}{4.741253in}}%
# \pgfpathquadraticcurveto{\pgfqpoint{5.887648in}{4.741253in}}{\pgfqpoint{5.887648in}{4.721808in}}%
# \pgfpathlineto{\pgfqpoint{5.887648in}{3.375822in}}%
# \pgfpathquadraticcurveto{\pgfqpoint{5.887648in}{3.356378in}}{\pgfqpoint{5.907092in}{3.356378in}}%
# \pgfpathlineto{\pgfqpoint{5.907092in}{3.356378in}}%
# \pgfpathclose%
# \pgfusepath{stroke,fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.472059,0.669118,0.786765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{4.634308in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.634308in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.702364in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.702364in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.634308in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=4.634308in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}GPT-3.5-turbo-1106}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.260784,0.499020,0.672549}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{4.498738in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.498738in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.566793in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.566793in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.498738in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=4.498738in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}GPT-3.5-turbo-1106 + CECRL}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.795588,0.369118,0.157353}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{4.363167in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.363167in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.431222in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.431222in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.363167in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=4.363167in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Mistral-7B + CECRL}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.875000,0.875000,0.125000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{4.227596in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.227596in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.295652in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.295652in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.227596in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=4.227596in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}CamemBERT}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.483333,0.453922,0.659804}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{4.092025in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.092025in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.160081in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.160081in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.092025in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=4.092025in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Davinci-002 + CECRL}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.638235,0.626471,0.761765}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.956454in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.956454in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{4.024510in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{4.024510in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.956454in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.956454in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Davinci-002}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.897549,0.568137,0.329902}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.820883in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.820883in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.888939in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.888939in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.820883in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.820883in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Mistral-7B}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.248039,0.583333,0.350980}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.685313in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.685313in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.753368in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.753368in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.685313in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.685313in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}GFI}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.494118,0.729412,0.500000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.549742in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.549742in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.617797in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.617797in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.549742in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.549742in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}ARI}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{0.655882,0.820588,0.638235}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.926537in}{3.414171in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.414171in}}%
# \pgfpathlineto{\pgfqpoint{6.120981in}{3.482227in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.482227in}}%
# \pgfpathlineto{\pgfqpoint{5.926537in}{3.414171in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=6.198759in,y=3.414171in,left,base]{\color{textcolor}{\rmfamily\fontsize{7.000000}{8.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}FKGL}}%
# \end{pgfscope}%
# \end{pgfpicture}%
# \makeatother%
# \endgroup%

# %%
# ----------------------------- CONFUSION MATRIX ----------------------------- #
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot as plt
import matplotlib
import seaborn as sns

matplotlib.use("pgf")
matplotlib.rcParams.update(
    {
        "pgf.texsystem": "pdflatex",
        "font.family": "serif",
        "font.size": 12,
        "text.usetex": True,
        "pgf.rcfonts": False,
    }
)

FONTSIZE = 8

# Create confusion matrix for each dataset
confusion_matrices = {}

for dataset_name, df in predictions.items():
    confusion_matrices[dataset_name] = confusion_matrix(df["y_true"], df["y_pred"])

# Plot confusion matrix
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
# Delete last subplot
fig.delaxes(axes[1, 1])

for i, (dataset_name, cm) in enumerate(confusion_matrices.items()):
    ax = axes[i // 2, i % 2]
    if dataset_name == "LjL":
        ax.set_title(f"{dataset_name} (gpt-3.5-turbo-1106 without context)")
    elif dataset_name == "SentencesInternet":
        ax.set_title(f"{dataset_name} (gpt-3.5-turbo-1106 with context)")
    else:
        ax.set_title(f"{dataset_name} (camembert-base)")
    ax.set_xlabel("Predicted label")
    ax.set_ylabel("True label")
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        ax=ax,
        cmap=sns.light_palette("green", as_cmap=True),
        cbar=False,
        annot_kws={"fontsize": 12},
    )
    if dataset_name != "LjL":
        ax.set_xticklabels(["A1", "A2", "B1", "B2", "C1", "C2"])
        ax.set_yticklabels(["A1", "A2", "B1", "B2", "C1", "C2"])
    else:
        ax.set_xticklabels(["Level 1", "Level 2", "Level 3", "Level 4"])
        ax.set_yticklabels(["Level 1", "Level 2", "Level 3", "Level 4"])

    ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=FONTSIZE)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=FONTSIZE)
    ax.set_ylim(len(cm), -0.5)
    ax.set_xlim(-0.5, len(cm))
    ax.set_aspect("equal")

    # Set axis labels (True VS Predicted)
    ax.set_xlabel("Predicted label", fontsize=FONTSIZE + 2)
    ax.set_ylabel("True label", fontsize=FONTSIZE + 2)

    # Set title font size
    ax.title.set_size(FONTSIZE + 4)

# Make graph more compact
plt.tight_layout()

# Export to latex
path = os.path.join(pwd, "figures", "difficulty_estimation", "confusion_matrix.pgf")
if not os.path.exists(os.path.dirname(path)):
    os.makedirs(os.path.dirname(path))
plt.savefig(path)

# Display latex
with open(path, "r") as file:
    latex = file.read()
print(latex)
# Out:
# %% Creator: Matplotlib, PGF backend
# %%
# %% To include the figure in your LaTeX document, write
# %%   \input{<filename>.pgf}
# %%
# %% Make sure the required packages are loaded in your preamble
# %%   \usepackage{pgf}
# %%
# %% Also ensure that all the required font packages are loaded; for instance,
# %% the lmodern package is sometimes necessary when using math font.
# %%   \usepackage{lmodern}
# %%
# %% Figures using additional raster images can only be included by \input if
# %% they are in the same directory as the main LaTeX file. For loading figures
# %% from other directories you can use the `import` package
# %%   \usepackage{import}
# %%
# %% and then include the figures with
# %%   \import{<path to file>}{<filename>.pgf}
# %%
# %% Matplotlib used the following preamble
# %%   \def\mathdefault#1{#1}
# %%   \everymath=\expandafter{\the\everymath\displaystyle}
# %%
# %%   \makeatletter\@ifpackageloaded{underscore}{}{\usepackage[strings]{underscore}}\makeatother
# %%
# \begingroup%
# \makeatletter%
# \begin{pgfpicture}%
# \pgfpathrectangle{\pgfpointorigin}{\pgfqpoint{10.000000in}{10.000000in}}%
# \pgfusepath{use as bounding box, clip}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{10.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{10.000000in}{10.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{10.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.846732in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{4.993399in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{4.993399in}{9.611667in}}%
# \pgfpathlineto{\pgfqpoint{0.846732in}{9.611667in}}%
# \pgfpathlineto{\pgfqpoint{0.846732in}{5.465000in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.555466,0.774185,0.555412}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.307473in}{9.150926in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{9.150926in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{1.307473in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{1.307473in}{9.150926in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.847627,0.917369,0.847544}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.228955in}{9.150926in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{9.150926in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{9.150926in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.912551,0.949187,0.912462}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.150436in}{9.150926in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{9.150926in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{9.150926in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.919765,0.952722,0.919676}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.071918in}{9.150926in}}%
# \pgfpathlineto{\pgfqpoint{4.993399in}{9.150926in}}%
# \pgfpathlineto{\pgfqpoint{4.993399in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{9.150926in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.825985,0.906762,0.825905}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.307473in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{1.307473in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{1.307473in}{8.229444in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.093780,0.547921,0.093771}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.228955in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{8.229444in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.703350,0.846661,0.703281}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.150436in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{8.229444in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.872875,0.929742,0.872790}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.071918in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{4.993399in}{8.229444in}}%
# \pgfpathlineto{\pgfqpoint{4.993399in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{8.229444in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.919765,0.952722,0.919676}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.307473in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{1.307473in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{1.307473in}{7.307963in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.836806,0.912066,0.836724}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.228955in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{7.307963in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.501961,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.150436in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{7.307963in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.667281,0.828984,0.667216}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.071918in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{4.993399in}{7.307963in}}%
# \pgfpathlineto{\pgfqpoint{4.993399in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{7.307963in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.919765,0.952722,0.919676}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{1.307473in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{1.307473in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{1.307473in}{6.386481in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.912551,0.949187,0.912462}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{2.228955in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{2.228955in}{6.386481in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.678101,0.834287,0.678035}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{3.150436in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{3.150436in}{6.386481in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{0.846732in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.187560,0.593881,0.187542}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{4.071918in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{4.993399in}{6.386481in}}%
# \pgfpathlineto{\pgfqpoint{4.993399in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{4.071918in}{6.386481in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{1.768214in}{5.465000in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.768214in,y=5.367778in,,top]{\color{textcolor}{\rmfamily\fontsize{8.000000}{9.600000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Level 1}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{2.689695in}{5.465000in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.689695in,y=5.367778in,,top]{\color{textcolor}{\rmfamily\fontsize{8.000000}{9.600000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Level 2}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{3.611177in}{5.465000in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.611177in,y=5.367778in,,top]{\color{textcolor}{\rmfamily\fontsize{8.000000}{9.600000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Level 3}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{4.532658in}{5.465000in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.532658in,y=5.367778in,,top]{\color{textcolor}{\rmfamily\fontsize{8.000000}{9.600000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Level 4}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.920066in,y=5.213457in,,top]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Predicted label}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.846732in}{8.690185in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.749510in,y=8.690185in,right,]{\color{textcolor}{\rmfamily\fontsize{8.000000}{9.600000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Level 1}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.846732in}{7.768704in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.749510in,y=7.768704in,right,]{\color{textcolor}{\rmfamily\fontsize{8.000000}{9.600000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Level 2}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.846732in}{6.847222in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.749510in,y=6.847222in,right,]{\color{textcolor}{\rmfamily\fontsize{8.000000}{9.600000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Level 3}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.846732in}{5.925741in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.749510in,y=5.925741in,right,]{\color{textcolor}{\rmfamily\fontsize{8.000000}{9.600000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}Level 4}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.325083in,y=7.538333in,,bottom,rotate=90.000000]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}True label}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.768214in,y=8.690185in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}39}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.689695in,y=8.690185in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}8}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.611177in,y=8.690185in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}1}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.532658in,y=8.690185in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.768214in,y=7.768704in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}10}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.689695in,y=7.768704in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}88}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.611177in,y=7.768704in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}23}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.532658in,y=7.768704in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}5}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.768214in,y=6.847222in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.689695in,y=6.847222in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}9}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.611177in,y=6.847222in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}98}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.532658in,y=6.847222in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}27}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.768214in,y=5.925741in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.689695in,y=5.925741in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}1}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.611177in,y=5.925741in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}26}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.532658in,y=5.925741in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}78}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.920066in,y=9.695000in,,base]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}LjL (gpt-3.5-turbo-1106 without context)}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.640343in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{9.787010in}{5.465000in}}%
# \pgfpathlineto{\pgfqpoint{9.787010in}{9.611667in}}%
# \pgfpathlineto{\pgfqpoint{5.640343in}{9.611667in}}%
# \pgfpathlineto{\pgfqpoint{5.640343in}{5.465000in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.111815,0.556759,0.111804}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.959317in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{5.959317in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{5.959317in}{9.292692in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.887303,0.936813,0.887216}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.597266in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{9.292692in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.908944,0.947419,0.908856}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.235215in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{9.292692in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.898124,0.942116,0.898036}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.873163in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{9.292692in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.876482,0.931510,0.876397}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{8.511112in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{9.292692in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.919765,0.952722,0.919676}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{9.149061in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{9.787010in}{9.292692in}}%
# \pgfpathlineto{\pgfqpoint{9.787010in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{9.292692in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.908944,0.947419,0.908856}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.959317in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{5.959317in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{5.959317in}{8.654744in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.032462,0.517870,0.032459}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.597266in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{8.654744in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.919765,0.952722,0.919676}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.235215in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{8.654744in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.908944,0.947419,0.908856}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.873163in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{8.654744in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.908944,0.947419,0.908856}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{8.511112in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{8.654744in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.919765,0.952722,0.919676}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{9.149061in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{9.787010in}{8.654744in}}%
# \pgfpathlineto{\pgfqpoint{9.787010in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{8.654744in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.862055,0.924439,0.861970}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.959317in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{5.959317in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{5.959317in}{8.016795in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.898124,0.942116,0.898036}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.597266in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{8.016795in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.137063,0.569133,0.137050}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.235215in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{8.016795in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.862055,0.924439,0.861970}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.873163in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{8.016795in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.919765,0.952722,0.919676}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{8.511112in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{8.016795in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.919765,0.952722,0.919676}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{9.149061in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{9.787010in}{8.016795in}}%
# \pgfpathlineto{\pgfqpoint{9.787010in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{8.016795in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.887303,0.936813,0.887216}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.959317in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{5.959317in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{5.959317in}{7.378846in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.898124,0.942116,0.898036}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.597266in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{7.378846in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.851234,0.919136,0.851151}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.235215in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{7.378846in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.205595,0.602719,0.205575}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.873163in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{7.378846in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.840413,0.913833,0.840331}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{8.511112in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{8.511112in}{7.378846in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.919765,0.952722,0.919676}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{9.149061in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{9.787010in}{7.378846in}}%
# \pgfpathlineto{\pgfqpoint{9.787010in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{9.149061in}{7.378846in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.898124,0.942116,0.898036}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.959317in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{6.102949in}}%
# \pgfpathlineto{\pgfqpoint{5.959317in}{6.102949in}}%
# \pgfpathlineto{\pgfqpoint{5.959317in}{6.740897in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.919765,0.952722,0.919676}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{6.597266in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{6.102949in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{6.102949in}}%
# \pgfpathlineto{\pgfqpoint{6.597266in}{6.740897in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.919765,0.952722,0.919676}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{7.235215in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{6.740897in}}%
# \pgfpathlineto{\pgfqpoint{7.873163in}{6.102949in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{6.102949in}}%
# \pgfpathlineto{\pgfqpoint{7.235215in}{6.740897in}}%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfpathrectangle{\pgfqpoint{5.640343in}{5.465000in}}{\pgfqpoint{4.146667in}{4.146667in}}%
# \pgfusepath{clip}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.887303,0.936813,0.887216}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# ...
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.846732in}{2.149872in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.749510in,y=2.149872in,right,]{\color{textcolor}{\rmfamily\fontsize{8.000000}{9.600000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}B2}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.846732in}{1.511923in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.749510in,y=1.511923in,right,]{\color{textcolor}{\rmfamily\fontsize{8.000000}{9.600000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}C1}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.846732in}{0.873974in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.749510in,y=0.873974in,right,]{\color{textcolor}{\rmfamily\fontsize{8.000000}{9.600000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}C2}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.546499in,y=2.628333in,,bottom,rotate=90.000000]{\color{textcolor}{\rmfamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}True label}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.484681in,y=4.063718in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}118}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.122630in,y=4.063718in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}30}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.760579in,y=4.063718in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}12}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.398527in,y=4.063718in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.036476in,y=4.063718in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.674425in,y=4.063718in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.484681in,y=3.425769in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}51}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.122630in,y=3.425769in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}53}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.760579in,y=3.425769in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}54}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.398527in,y=3.425769in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}2}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.036476in,y=3.425769in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.674425in,y=3.425769in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.484681in,y=2.787821in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}12}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.122630in,y=2.787821in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}27}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.760579in,y=2.787821in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}99}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.398527in,y=2.787821in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}21}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.036476in,y=2.787821in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}1}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.674425in,y=2.787821in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.484681in,y=2.149872in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}1}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.122630in,y=2.149872in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}1}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.760579in,y=2.149872in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}22}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.398527in,y=2.149872in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}108}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.036476in,y=2.149872in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}22}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.674425in,y=2.149872in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}6}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.484681in,y=1.511923in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}1}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.122630in,y=1.511923in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.760579in,y=1.511923in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}9}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.398527in,y=1.511923in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}84}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.036476in,y=1.511923in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}41}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.674425in,y=1.511923in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}25}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.484681in,y=0.873974in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.122630in,y=0.873974in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.760579in,y=0.873974in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}4}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.398527in,y=0.873974in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}30}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.150000,0.150000,0.150000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.036476in,y=0.873974in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}43}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.674425in,y=0.873974in,,]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}83}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.920066in,y=4.785000in,,base]{\color{textcolor}{\rmfamily\fontsize{12.000000}{14.400000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}SentencesBooks (camembert-base)}}%
# \end{pgfscope}%
# \end{pgfpicture}%
# \makeatother%
# \endgroup%
