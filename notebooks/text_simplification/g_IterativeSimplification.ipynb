# %% [markdown]
# # Iterative Simplification
#
# The aim of this notebook is to evaluate the effectiveness of our simplification method by applying it iteratively.
# > How does the simplicity of a sentence evolve when it is iteratively simplified?
# > How does the similarity with the original sentence evolve?

# %%
# ---------------------------- PREPARING NOTEBOOK ---------------------------- #
# Autoreload
# %load_ext autoreload
# %autoreload 2

# Random seed
import numpy as np
np.random.seed(42)

# External modules
import os
from IPython.display import display

# Set global log level
import logging
logging.basicConfig(level=logging.INFO)
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

# Define PWD as the current git repository
import git
repo = git.Repo('.', search_parent_directories=True)
pwd = repo.working_dir
os.chdir(pwd)

# import

# %%
# -------------------------- LOAD PREVIOUS NOTEBOOKS ------------------------- #
import json
import __main__
import black
import types

paths = [
    os.path.join(pwd, "notebooks", "text_simplification", "a_DatasetCreation.ipynb"),
    os.path.join(pwd, "notebooks", "text_simplification", "c_MistralEvaluation.ipynb"),
    os.path.join(pwd, "notebooks", "text_simplification", "d_Metrics.ipynb"),
]

# Read notebooks
code_dict = {}
for path in paths:
    code = ""
    with open(path, "r") as f:
        temp = json.load(f)

    cells = [
        cell
        for cell in temp["cells"]
        if cell["cell_type"] == "code"
        and len(cell["source"]) > 0
        and cell["source"][-1] == "# import"
    ]
    notebook_code = "\n".join(
        line
        for cell in cells
        for line in cell["source"]
        if line != "# import" and len(line) > 0 and line[0] != "%"
    )
    # Create something like a header
    code += f"# {'-'*76} #\n"
    code += f"# {os.path.basename(path).upper():^76} #\n"
    code += f"# {'-'*76} #\n"
    code += notebook_code

    # Add "Module Creation"
    notebook_name = (
        os.path.basename(path).replace("imported_", "").replace(".ipynb", "")
    )
    code += """
# --------------------------------- IMPORTER --------------------------------- #
import types


class MyNotebook:
    pass


NOTEBOOK_NAME = MyNotebook()
# Put every function defined in the notebook in the class
NOTEBOOK_NAME.__dict__.update(
    {
        name: obj
        for name, obj in locals().items()
        if isinstance(obj, (type, types.FunctionType))
        if not (name.startswith("_") or name == "MyNotebook")
    }
)
    """.replace(
        "NOTEBOOK_NAME", notebook_name
    )

    # Remove empty lines
    code = "\n".join([line for line in code.split("\n") if len(line) > 0])
    # Format code
    code = black.format_str(code, mode=black.FileMode())

    # Write scrach file
    path = os.path.join(
        pwd, "scratch", f"imported_{os.path.basename(path).replace('ipynb', 'py')}"
    )
    if not os.path.exists(os.path.dirname(path)):
        os.makedirs(os.path.dirname(path))
    with open(path, "w") as f:
        f.write(code)
    code_dict[path] = code


# Mainify code
for path, code in code_dict.items():
    compiled = compile(code, path, "exec")
    exec(compiled, __main__.__dict__)

# import

# %% [markdown]
# ## Creation of the data set
#
# In order to evaluate the evolution of the complexity and similarity of a simplified sentence, we will create a dataset of C2 sentences correctly classified by **BERT**. We will then iteratively simplify these sentences and evaluate the evolution of complexity and similarity.

# %%
# ----------------------------- DATASET CREATION ----------------------------- #
import pandas as pd

# Loading full dataset
test_df = c_MistralEvaluation.download_difficulty_estimation(pwd)
test_df = c_MistralEvaluation.get_balanced_dataframe(test_df, None)
test_df = test_df[test_df["Difficulty"] == "C2"]

# Get Bert predictions
predictions = d_Metrics.get_bert_difficulty_prediction(
    test_df["Sentence"], dataset="french_difficulty", pwd=os.path.join(pwd, "scratch")
)

# Keep only the sentences correctly predicted
test_df = test_df[test_df["Difficulty"] == predictions].reset_index(drop=True)

# Display
display(test_df.head())
# Out:
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# /home/lopilo/.cache/pypoetry/virtualenvs/lingorank-llm-wa__1Cox-py3.9/lib/python3.9/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.3.2 when using version 1.4.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#                                             Sentence Difficulty
# 0  Le seul point de vue raisonnable que puisse of...         C2
# 1  Or, sous ce point de vue, chacune d'elles corr...         C2
# 2  Préparé, au contraire, par une éducation mathé...         C2
# 3  Aussi, à toutes les époques du développement s...         C2
# 4  En vertu du nombre, déjà très considérable, et...         C2

# %% [markdown]
# ## A simulation stage + Evaluation
#
# We are now going to define a function that will perform a simplification step on a set of sentences using our **Mistral-7B** fine-tuned model. We will then evaluate the similarity and the difference in difficulty evaluated by **BERT** between the simplified sentences and the original sentences.

# %% [markdown]
# ### Simplification step
#
# Let's start by defining a function that takes a list of sentences as input and returns a list of simplified sentences using our **Mistral-7B** fine-tuned model.

# %%
# -------------------------- MISTRAL SIMPLIFICATION -------------------------- #
import os

import pandas as pd
import torch
from peft import PeftModel
from torch.utils.data import DataLoader
from transformers import AutoModelForCausalLM
from tqdm import tqdm as console_tqdm
from slurmray.RayLauncher import RayLauncher
import ray

MODEL = "bofenghuang/vigostral-7b-chat"


# Define cluster function
@ray.remote(num_gpus=1)  # Indique que chaque tâche nécessite un GPU
def worker_mistral_simplify(
    test_df: pd.DataFrame,
    pwd: str = "/scratch/hjamet",
):
    # Fix partial import bug
    import ray.train.huggingface
    import ray.train.huggingface.transformers

    # Charger tokenizer
    tokenizer = a_DatasetCreation.download_tokenizer(training=False)

    # Create dataset
    dataset = a_DatasetCreation.format_data(test_df, tokenizer, training=False)

    # Encode dataset
    encoded_dataset = a_DatasetCreation.encode_dataset(dataset, tokenizer)

    # Load model
    path = os.path.join(
        pwd,
        "models",
        "difficulty_estimation",
        MODEL.replace("/", "_"),
    )
    base_model = AutoModelForCausalLM.from_pretrained(
        os.path.join(path, "mistral_simplification_trained"),
        device_map="auto",
        use_cache=False,
        trust_remote_code=True,
    )
    model = PeftModel.from_pretrained(
        base_model, os.path.join(path, "mistral_simplification_trained")
    )

    # Move everything to GPU
    model.to("cuda")
    test_loader = DataLoader(encoded_dataset, batch_size=8)

    # Generate predictions
    with torch.no_grad():
        model.eval()
        predictions_ids = []

        for batch in console_tqdm(test_loader):
            input_ids_batch = batch["input_ids"].to("cuda")
            attention_mask_batch = batch["attention_mask"].to("cuda")

            outputs = model.generate(
                input_ids=input_ids_batch,
                attention_mask=attention_mask_batch,
                max_length=max(128, input_ids_batch.shape[1] * 2),
                num_return_sequences=1,
            )

            predictions_ids.extend(outputs)
        predictions = [
            tokenizer.decode(prediction, skip_special_tokens=True)
            for prediction in predictions_ids
        ]
        predictions_series = pd.Series(predictions)

    return predictions_series


def cluster_mistral_simplify(test_df: pd.DataFrame, pwd: str = "/scratch/hjamet"):
    # Split the DataFrame into chunks for parallel processing
    num_gpus = ray.cluster_resources()["GPU"]
    chunk_size = int(len(test_df) / num_gpus)
    chunks = [test_df[i : i + chunk_size] for i in range(0, len(test_df), chunk_size)]

    # Distribute the work to the GPUs
    futures = [worker_mistral_simplify.remote(chunk, pwd) for chunk in chunks]

    # Collect the results from the GPUs
    predictions_series = pd.concat(ray.get(futures))

    return predictions_series


# Define launcher function
def mistral_simplify(test_df: pd.DataFrame, save_n: int = None, ssh_key: str = None):
    # Define ray launcher
    launcher = RayLauncher(
        project_name="mistral_sentence_simplification",
        func=cluster_mistral_simplify,
        args={"test_df": test_df, "pwd": "/scratch/hjamet"},
        modules=[],
        node_nbr=3,
        use_gpu=True,
        memory=128,
        max_running_time=60,
        server_run=True,
        server_ssh="curnagl.dcsr.unil.ch",
        server_username="hjamet",
        server_password=ssh_key,
    )

    # Run inference
    predictions = launcher()

    # Save predictions
    if save_n is not None:
        path = os.path.join(
            pwd,
            "results",
            "text_simplification",
            "IterativeSimplification",
        )
        if not os.path.exists(path):
            os.makedirs(path)
        predictions.to_csv(
            os.path.join(
                path,
                f"{save_n}_simplified_raw.csv",
            ),
            index=False,
        )

    # Format predictions
    predictions_df = pd.concat(
        [
            test_df.reset_index(drop=True),
            predictions.str.extract(r"\[/INST\] (.*[\.\n])")
            .iloc[:, 0]
            .rename("Simplified")
            .str.strip()
            .reset_index(drop=True),
        ],
        axis=1,
    )

    # Save formatted predictions
    if save_n is not None:
        predictions_df.to_csv(
            os.path.join(
                path,
                f"{save_n}_simplified_formatted.csv",
            ),
            index=False,
        )

    return predictions_df

# %%
predictions_df = mistral_simplify(test_df.iloc[:10])
# Out:
# Serializing function and arguments...
# Connecting to the cluster...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.42.0)
# Requirement already satisfied: black in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (24.1.1)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.5.6)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.16.1)
# Requirement already satisfied: deepspeed in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.13.1)
# Requirement already satisfied: einops in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.109.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: inquirerpy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (0.3.4)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (1.6.3)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.1.1)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (8.3.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (1.10.0)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.11.4)
# Requirement already satisfied: pathtools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.1.2)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.7.1)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (1.0.1)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (13.7.0)
# Requirement already satisfied: rouge-score in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (0.1.2)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.1.1)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: sentence-transformers in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (2.3.1)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.5.2)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (2.1.1)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (0.16.1)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.27.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (20.25.0)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.16.2)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (3.5.7)
# Requirement already satisfied: torch==2.1.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 46)) (2.1.1)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (3.13.1)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (4.9.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (1.12)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (3.2.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (3.1.3)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.venv/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.1->-r requirements.txt (line 46)) (12.3.101)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.2)
# Requirement already satisfied: scipy in ./.venv/lib/python3.9/site-packages (from bitsandbytes->-r requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: tomli>=1.1.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (1.26.3)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: huggingface-hub>=0.19.4 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: hjson in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: ninja in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (1.11.1.1)
# Requirement already satisfied: psutil in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (5.9.8)
# Requirement already satisfied: py-cpuinfo in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (9.0.0)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (2.5.3)
# Requirement already satisfied: pynvml in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (11.5.0)
# Requirement already satisfied: starlette<0.36.0,>=0.35.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 9)) (0.35.1)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (12.535.133)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (1.20.0)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from inquirerpy->-r requirements.txt (line 13)) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from inquirerpy->-r requirements.txt (line 13)) (3.0.43)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (8.0.2)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 17)) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (0.26.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (1.3.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (2.15.0)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 22)) (4.37.1)
# Requirement already satisfied: accelerate>=0.21.0 in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 22)) (0.26.1)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 22)) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 25)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 25)) (2.17.2)
# Requirement already satisfied: absl-py in ./.venv/lib/python3.9/site-packages (from rouge-score->-r requirements.txt (line 26)) (2.1.0)
# Requirement already satisfied: nltk in ./.venv/lib/python3.9/site-packages (from rouge-score->-r requirements.txt (line 26)) (3.8.1)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 27)) (2023.12.25)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 27)) (1.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 28)) (3.8.2)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from sentence-transformers->-r requirements.txt (line 29)) (1.4.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from sentence-transformers->-r requirements.txt (line 29)) (0.1.99)
# Requirement already satisfied: Pillow in ./.venv/lib/python3.9/site-packages (from sentence-transformers->-r requirements.txt (line 29)) (10.2.0)
# Requirement already satisfied: protobuf>=3.20 in ./.venv/lib/python3.9/site-packages (from tensorboardx->-r requirements.txt (line 31)) (4.23.4)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 32)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 34)) (2.15.1)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 38)) (0.14.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 40)) (0.3.8)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (3.1.41)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (1.39.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (0.4.0)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (1.3.3)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (58.1.0)
# Requirement already satisfied: appdirs>=1.4.3 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (1.4.4)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 45)) (3.4.0)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 45)) (0.10.0)
# Requirement already satisfied: pip-chill<2.0.0,>=1.0.3 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 45)) (1.0.3)
# Requirement already satisfied: ray<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (2.9.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 19)) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 19)) (1.2.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 14)) (2.8.19.20240106)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 11)) (0.2.13)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 41)) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (1.62.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (2.27.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 19)) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 25)) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.4)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (4.1.2)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (42.0.1)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (1.5.0)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 45)) (3.5.2)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.9/site-packages (from pydantic->deepspeed->-r requirements.txt (line 7)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in ./.venv/lib/python3.9/site-packages (from pydantic->deepspeed->-r requirements.txt (line 7)) (2.14.6)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (4.21.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (1.0.7)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (0.19.0)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (1.60.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (1.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (3.0.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 22)) (0.15.1)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 16)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.1.1->-r requirements.txt (line 46)) (2.1.4)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (7.0.7)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (5.5.1)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (7.14.2)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (6.29.0)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (8.1.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 16)) (1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 29)) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.1.1->-r requirements.txt (line 46)) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 41)) (5.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 45)) (7.0.1)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.1.6)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (5.14.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 17)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 17)) (3.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (0.17.1)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (4.12.3)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (0.9.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.12.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 17)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (2.21)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.19.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (4.9.0)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.5.2)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (7.7.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.18.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.2.2)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.9.14)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (2.19.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (3.2.2)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.2.2)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1402-16h08.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1402-16h08_queue.log>
# Submitted batch job 38690509
# IP Head: 10.203.101.82:6379
# STARTING HEAD at dnagpu002
# 2024-02-14 16:08:28,020	INFO usage_lib.py:449 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-02-14 16:08:28,021	INFO scripts.py:744 -- Local node IP: 10.203.101.82
# 2024-02-14 16:08:33,227	SUCC scripts.py:781 -- --------------------
# 2024-02-14 16:08:33,227	SUCC scripts.py:782 -- Ray runtime started.
# 2024-02-14 16:08:33,227	SUCC scripts.py:783 -- --------------------
# 2024-02-14 16:08:33,227	INFO scripts.py:785 -- Next steps
# 2024-02-14 16:08:33,229	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-02-14 16:08:33,229	INFO scripts.py:791 --   ray start --address='10.203.101.82:6379'
# 2024-02-14 16:08:33,229	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-02-14 16:08:33,229	INFO scripts.py:802 -- import ray
# 2024-02-14 16:08:33,229	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.82')
# 2024-02-14 16:08:33,229	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-02-14 16:08:33,229	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.82:8265' ray job submit --working-dir . -- python my_script.py
# 2024-02-14 16:08:33,229	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-02-14 16:08:33,229	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-02-14 16:08:33,229	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-02-14 16:08:33,229	INFO scripts.py:835 --   ray stop
# 2024-02-14 16:08:33,229	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-02-14 16:08:33,229	INFO scripts.py:839 --   ray status
# 2024-02-14 16:08:33,229	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-02-14 16:08:33,229	INFO scripts.py:844 --   10.203.101.82:8265
# 2024-02-14 16:08:33,229	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-02-14 16:08:33,230	INFO scripts.py:952 -- --block
# 2024-02-14 16:08:33,230	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 16:08:33,230	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# STARTING WORKER 1 at dnagpu003
# STARTING WORKER 2 at dnagpu004
# 2024-02-14 16:08:57,234	INFO worker.py:1540 -- Connecting to existing Ray cluster at address: 10.203.101.82:6379...
# 2024-02-14 16:08:57,242	INFO worker.py:1715 -- Connected to Ray cluster. View the dashboard at 10.203.101.82:8265
# [2024-02-14 16:09:04,026 I 414249 414249] global_state_accessor.cc:432: This node has an IP address of 10.203.101.84, but we cannot find a local Raylet with the same address. This can happen when you connect to the Ray cluster with a different IP address or when connecting to a container.
# [2024-02-14 16:09:04,026 I 2543955 2543955] global_state_accessor.cc:432: This node has an IP address of 10.203.101.83, but we cannot find a local Raylet with the same address. This can happen when you connect to the Ray cluster with a different IP address or when connecting to a container.
# 2024-02-14 16:09:03,903	INFO scripts.py:926 -- Local node IP: 10.203.101.83
# 2024-02-14 16:09:04,027	SUCC scripts.py:939 -- --------------------
# 2024-02-14 16:09:03,923	INFO scripts.py:926 -- Local node IP: 10.203.101.84
# 2024-02-14 16:09:04,027	SUCC scripts.py:939 -- --------------------
# 2024-02-14 16:09:04,027	SUCC scripts.py:940 -- Ray runtime started.
# 2024-02-14 16:09:04,027	SUCC scripts.py:941 -- --------------------
# 2024-02-14 16:09:04,028	SUCC scripts.py:940 -- Ray runtime started.
# 2024-02-14 16:09:04,028	SUCC scripts.py:941 -- --------------------
# 2024-02-14 16:09:04,027	INFO scripts.py:943 -- To terminate the Ray runtime, run
# 2024-02-14 16:09:04,027	INFO scripts.py:944 --   ray stop
# 2024-02-14 16:09:04,028	INFO scripts.py:943 -- To terminate the Ray runtime, run
# 2024-02-14 16:09:04,028	INFO scripts.py:944 --   ray stop
# 2024-02-14 16:09:04,028	INFO scripts.py:952 -- --block
# 2024-02-14 16:09:04,028	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 16:09:04,028	INFO scripts.py:952 -- --block
# 2024-02-14 16:09:04,028	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 16:09:04,028	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-02-14 16:09:04,028	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# (worker_mistral_simplify pid=3129318)
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# (worker_mistral_simplify pid=3129318)
# Map:  33%|███▎      | 1/3 [00:00<00:00,  7.01 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 20.51 examples/s]
# (worker_mistral_simplify pid=3129318)
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 325.91 examples/s]
# (worker_mistral_simplify pid=3129318)
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 490.14 examples/s]
# (worker_mistral_simplify pid=3129318)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# (worker_mistral_simplify pid=3129318)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83)
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84)
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84)
# Map:  33%|███▎      | 1/3 [00:00<00:00,  4.67 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 11.20 examples/s]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84)
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83)
# Map: 100%|██████████| 3/3 [00:00<00:00, 421.89 examples/s]
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83)
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 550.82 examples/s]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84) /users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# (worker_mistral_simplify pid=414542, ip=10.203.101.84)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=3129318)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:32<00:32, 32.42s/it]
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83)
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83)
# Map:  33%|███▎      | 1/3 [00:00<00:00,  4.37 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 10.66 examples/s]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84)
# Map: 100%|██████████| 3/3 [00:00<00:00, 406.78 examples/s]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84)
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 519.01 examples/s]
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83) /users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:47<00:47, 47.08s/it]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:47<00:47, 47.13s/it]
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83)
# Loading checkpoint shards: 100%|██████████| 2/2 [01:12<00:00, 34.20s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [01:12<00:00, 36.13s/it]
# (worker_mistral_simplify pid=3129318) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# (worker_mistral_simplify pid=3129318) To disable this warning, you can either:
# (worker_mistral_simplify pid=3129318) 	- Avoid using `tokenizers` before the fork if possible
# (worker_mistral_simplify pid=3129318) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (worker_mistral_simplify pid=3129318) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# (worker_mistral_simplify pid=3129318) To disable this warning, you can either:
# (worker_mistral_simplify pid=3129318) 	- Avoid using `tokenizers` before the fork if possible
# (worker_mistral_simplify pid=3129318) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (worker_mistral_simplify pid=3129318)
# Loading checkpoint shards: 100%|██████████| 2/2 [01:28<00:00, 46.43s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [01:28<00:00, 44.32s/it] [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (worker_mistral_simplify pid=3129318)
#   0%|          | 0/1 [00:00<?, ?it/s]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks... [repeated 4x across cluster]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84) To disable this warning, you can either: [repeated 4x across cluster]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84) 	- Avoid using `tokenizers` before the fork if possible [repeated 4x across cluster]
# (worker_mistral_simplify pid=414542, ip=10.203.101.84) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false) [repeated 4x across cluster]
# (worker_mistral_simplify pid=3129318) Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=414542, ip=10.203.101.84)
#   0%|          | 0/1 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83)
# 100%|██████████| 1/1 [00:08<00:00,  8.33s/it]
# 100%|██████████| 1/1 [00:08<00:00,  8.33s/it]
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83)
#   0%|          | 0/1 [00:00<?, ?it/s]
# (worker_mistral_simplify pid=2544239, ip=10.203.101.83) Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83)
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1/1 [00:00<00:00, 23.26 examples/s]
# (worker_mistral_simplify pid=3129318)
# 100%|██████████| 1/1 [00:12<00:00, 12.04s/it]
# 100%|██████████| 1/1 [00:12<00:00, 12.04s/it]
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83)
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1/1 [00:00<00:00, 179.64 examples/s]
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83)
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1/1 [00:00<00:00, 218.62 examples/s]
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=414542, ip=10.203.101.84)
# 100%|██████████| 1/1 [00:26<00:00, 26.53s/it]
# 100%|██████████| 1/1 [00:26<00:00, 26.53s/it]
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:08<00:08,  8.29s/it]
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83)
# Loading checkpoint shards: 100%|██████████| 2/2 [00:12<00:00,  5.96s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:12<00:00,  6.31s/it]
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83) To disable this warning, you can either:
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83) 	- Avoid using `tokenizers` before the fork if possible
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83) To disable this warning, you can either:
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83) 	- Avoid using `tokenizers` before the fork if possible
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (worker_mistral_simplify pid=2544858, ip=10.203.101.83)
#   0%|          | 0/1 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Job finished!
# Downloading result...
# Result downloaded!

# %% [markdown]
# ### Assessment
#
# We are now going to evaluate the characteristics of the simplified sentences compared to the original sentences. To do this, we will use **BERT** to evaluate :
# - The similarity between the simplified sentences and the original sentences
# - The level of difficulty of the simplified sentences.

# %%
# ------------------------- BERT EVALUATION FUNCTION ------------------------- #
def bert_simplification_evaluation(
    predictions_df: pd.DataFrame,
    save_n: int = None,
):
    # Similarity
    similarity = d_Metrics.get_simplification_similarity(
        predictions_df.rename(columns={"Sentence": "Original"}),
    ).similarity
    predictions_df["Similarity"] = similarity

    # Estimated Difficulty
    difficulty = d_Metrics.get_bert_difficulty_prediction(
        predictions_df["Simplified"],
        dataset="french_difficulty",
        pwd=os.path.join(pwd, "scratch"),
    )
    predictions_df["Estimated_Difficulty"] = difficulty

    # Save predictions
    if save_n is not None:
        path = os.path.join(
            pwd,
            "results",
            "text_simplification",
            "IterativeSimplification",
        )
        if not os.path.exists(path):
            os.makedirs(path)
        predictions_df.to_csv(
            os.path.join(
                path,
                f"{save_n}_simplified_evaluation.csv",
            ),
            index=False,
        )

    return predictions_df

# %%
bert_simplification_evaluation(predictions_df)
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: camembert-base
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name camembert-base. Creating a new one with MEAN pooling.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/lopilo/.cache/pypoetry/virtualenvs/lingorank-llm-wa__1Cox-py3.9/lib/python3.9/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.3.2 when using version 1.4.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#                                             Sentence Difficulty  \
# 0  Le seul point de vue raisonnable que puisse of...         C2
# 1  Or, sous ce point de vue, chacune d'elles corr...         C2
# 2  Préparé, au contraire, par une éducation mathé...         C2
# 3  Aussi, à toutes les époques du développement s...         C2
# 4  En vertu du nombre, déjà très considérable, et...         C2
# 5  Mais, à partir des événemens physiques, la sus...         C2
# 6  Malheureusement l'admirable extension de la pu...         C2
# 7  Car, d'après les considérations sommairement i...         C2
# 8  Sous ce premier rapport, qui est décisif, la p...         C2
# 9  Qui pourrait méconnaître aujourd'hui que, par ...         C2
#
#                                           Simplified  Similarity  \
# 0  La seule façon raisonnable de voir un principe...    0.942184
# 1  Donc, selon cette approche, chaque lune corres...    0.966188
# 2  Bien éduqué en mathématiques et en astronomie,...    0.854498
# 3  Depuis que la chimie est devenue une science à...    0.921910
# 4  Beaucoup de corps chimiques simples sont étudi...    0.928633
# 5  Mais si on regarde les choses qui se passent d...    0.889296
# 6  Malheureusement, l'extension de la chimie aujo...    0.894255
# 7  Donc, selon ce que l'on a vu dans la leçon pré...    0.918746
# 8  Dans ce rapport important, on décide de la pla...    0.933345
# 9  Il est difficile de ne pas reconnaître aujourd...    0.892081
#
#   Estimated_Difficulty
# 0                   C1
# 1                   C2
# 2                   C1
# 3                   B1
# 4                   C1
# 5                   B1
# 6                   B2
# 7                   B1
# 8                   B2
# 9                   C2

# %% [markdown]
# ### Iterative simplification Step
#
# Finally, we just need to define a function that performs the simplification and evaluation iteratively.

# %%
from tqdm import notebook as notebook_tqdm
from getpass import getpass


def iterative_simplification(test_df: pd.DataFrame, n: int = 8, bert : bool = False):
    # Store Originals
    result = (
        test_df.copy().rename(columns={"Sentence": "Original"}).reset_index(drop=True)
    )

    # Ask for password
    ssh_key = getpass("Enter your cluster password: ")

    temp_df = test_df.copy()
    for i in notebook_tqdm.tqdm(range(n)):
        # Simplify
        temp_df = mistral_simplify(temp_df, save_n=i + 1, ssh_key=ssh_key)

        # Evaluate
        temp_df["Sentence"] = result["Original"]
        temp_df = temp_df.fillna("")
        temp_df = bert_simplification_evaluation(temp_df, save_n=i + 1)

        # Store
        temp_to_store = temp_df[["Simplified", "Similarity", "Estimated_Difficulty"]]
        temp_to_store.columns = [
            f"Simplified_{i}",
            f"Similarity_{i}",
            f"Difficulty_{i}",
        ]
        result = pd.concat([result, temp_to_store], axis=1)

        # For safety, save the result
        path = os.path.join(
            pwd,
            "scratch",
            "IterativeSimplification",
        )
        if not os.path.exists(path):
            os.makedirs(path)
        result.to_csv(
            os.path.join(
                path,
                "iterative_simplification.csv",
            ),
            index=False,
        )

        # Prepare next iteration
        temp_df = temp_df[["Simplified", "Estimated_Difficulty"]]
        temp_df.columns = ["Sentence", "Difficulty"]
        
        # Change Difficulty to real difficulty
        if not(bert):
            temp_df["Difficulty"] = ["C1", "B2", "B1", "A2"][min(i, 3)]

    return result

# %% [markdown]
# ## Final Evaluation
#
# Finally, we're going to produce our results using the entire dataset.

# %%
# Run iterative simplification
result = iterative_simplification(test_df.sample(100))

# Save result
result.dropna().to_csv(
    os.path.join(
        pwd,
        "results",
        "text_simplification",
        "IterativeSimplification",
        "iterative_simplification_label.csv",
    ),
    index=False,
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Serializing function and arguments...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# Connecting to the cluster...
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.42.0)
# Requirement already satisfied: black in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (24.1.1)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.5.6)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.16.1)
# Requirement already satisfied: deepspeed in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.13.1)
# Requirement already satisfied: einops in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.109.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: inquirerpy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (0.3.4)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (1.6.3)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.1.1)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (8.3.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (1.10.0)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.11.4)
# Requirement already satisfied: pathtools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.1.2)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.7.1)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (1.0.1)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (13.7.0)
# Requirement already satisfied: rouge-score in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (0.1.2)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.1.1)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: sentence-transformers in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (2.3.1)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.5.2)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (2.1.1)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (0.16.1)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.27.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (20.25.0)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.16.2)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (3.5.7)
# Requirement already satisfied: torch==2.1.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 46)) (2.1.1)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (3.13.1)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (4.9.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (1.12)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (3.2.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (3.1.3)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.venv/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.1->-r requirements.txt (line 46)) (12.3.101)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.2)
# Requirement already satisfied: scipy in ./.venv/lib/python3.9/site-packages (from bitsandbytes->-r requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: tomli>=1.1.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (1.26.3)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: huggingface-hub>=0.19.4 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: hjson in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: ninja in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (1.11.1.1)
# Requirement already satisfied: psutil in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (5.9.8)
# Requirement already satisfied: py-cpuinfo in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (9.0.0)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (2.5.3)
# Requirement already satisfied: pynvml in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (11.5.0)
# Requirement already satisfied: starlette<0.36.0,>=0.35.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 9)) (0.35.1)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (12.535.133)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (1.20.0)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from inquirerpy->-r requirements.txt (line 13)) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from inquirerpy->-r requirements.txt (line 13)) (3.0.43)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (8.0.2)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 17)) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (0.26.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (1.3.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (2.15.0)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 22)) (4.37.1)
# Requirement already satisfied: accelerate>=0.21.0 in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 22)) (0.26.1)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 22)) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 25)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 25)) (2.17.2)
# Requirement already satisfied: absl-py in ./.venv/lib/python3.9/site-packages (from rouge-score->-r requirements.txt (line 26)) (2.1.0)
# Requirement already satisfied: nltk in ./.venv/lib/python3.9/site-packages (from rouge-score->-r requirements.txt (line 26)) (3.8.1)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 27)) (2023.12.25)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 27)) (1.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 28)) (3.8.2)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from sentence-transformers->-r requirements.txt (line 29)) (1.4.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from sentence-transformers->-r requirements.txt (line 29)) (0.1.99)
# Requirement already satisfied: Pillow in ./.venv/lib/python3.9/site-packages (from sentence-transformers->-r requirements.txt (line 29)) (10.2.0)
# Requirement already satisfied: protobuf>=3.20 in ./.venv/lib/python3.9/site-packages (from tensorboardx->-r requirements.txt (line 31)) (4.23.4)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 32)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 34)) (2.15.1)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 38)) (0.14.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 40)) (0.3.8)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (3.1.41)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (1.39.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (0.4.0)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (1.3.3)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (58.1.0)
# Requirement already satisfied: appdirs>=1.4.3 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (1.4.4)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 45)) (3.4.0)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 45)) (0.10.0)
# Requirement already satisfied: pip-chill<2.0.0,>=1.0.3 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 45)) (1.0.3)
# Requirement already satisfied: ray<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (2.9.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 19)) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 19)) (1.2.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 14)) (2.8.19.20240106)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 11)) (0.2.13)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 41)) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (1.62.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (2.27.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 19)) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 25)) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.4)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (4.1.2)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (42.0.1)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (1.5.0)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 45)) (3.5.2)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.9/site-packages (from pydantic->deepspeed->-r requirements.txt (line 7)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in ./.venv/lib/python3.9/site-packages (from pydantic->deepspeed->-r requirements.txt (line 7)) (2.14.6)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (4.21.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (1.0.7)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (0.19.0)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (1.60.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (1.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (3.0.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 22)) (0.15.1)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 16)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.1.1->-r requirements.txt (line 46)) (2.1.4)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (7.0.7)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (5.5.1)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (7.14.2)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (6.29.0)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (8.1.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 16)) (1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 29)) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.1.1->-r requirements.txt (line 46)) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 41)) (5.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 45)) (7.0.1)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.1.6)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (5.14.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 17)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 17)) (3.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (0.17.1)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (4.12.3)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (0.9.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.12.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 17)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (2.21)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.19.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (4.9.0)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.5.2)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (7.7.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.18.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.2.2)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.9.14)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (2.19.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (3.2.2)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.2.2)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1402-16h22.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1402-16h22_queue.log>
# Submitted batch job 38691905
# IP Head: 10.203.101.85:6379
# STARTING HEAD at dnagpu005
# 2024-02-14 16:22:43,705	INFO usage_lib.py:449 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-02-14 16:22:43,706	INFO scripts.py:744 -- Local node IP: 10.203.101.85
# 2024-02-14 16:22:48,741	SUCC scripts.py:781 -- --------------------
# 2024-02-14 16:22:48,742	SUCC scripts.py:782 -- Ray runtime started.
# 2024-02-14 16:22:48,742	SUCC scripts.py:783 -- --------------------
# 2024-02-14 16:22:48,742	INFO scripts.py:785 -- Next steps
# 2024-02-14 16:22:48,743	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-02-14 16:22:48,743	INFO scripts.py:791 --   ray start --address='10.203.101.85:6379'
# 2024-02-14 16:22:48,743	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-02-14 16:22:48,743	INFO scripts.py:802 -- import ray
# 2024-02-14 16:22:48,744	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.85')
# 2024-02-14 16:22:48,744	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-02-14 16:22:48,744	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.85:8265' ray job submit --working-dir . -- python my_script.py
# 2024-02-14 16:22:48,744	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-02-14 16:22:48,744	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-02-14 16:22:48,744	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-02-14 16:22:48,744	INFO scripts.py:835 --   ray stop
# 2024-02-14 16:22:48,744	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-02-14 16:22:48,744	INFO scripts.py:839 --   ray status
# 2024-02-14 16:22:48,744	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-02-14 16:22:48,744	INFO scripts.py:844 --   10.203.101.85:8265
# 2024-02-14 16:22:48,744	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-02-14 16:22:48,744	INFO scripts.py:952 -- --block
# 2024-02-14 16:22:48,744	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 16:22:48,744	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# STARTING WORKER 1 at dnagpu006
# STARTING WORKER 2 at dnagpu007
# [2024-02-14 16:23:00,647 I 1702074 1702074] global_state_accessor.cc:432: This node has an IP address of 10.203.101.86, but we cannot find a local Raylet with the same address. This can happen when you connect to the Ray cluster with a different IP address or when connecting to a container.
# 2024-02-14 16:23:00,567	INFO scripts.py:926 -- Local node IP: 10.203.101.86
# 2024-02-14 16:23:00,668	SUCC scripts.py:939 -- --------------------
# 2024-02-14 16:23:00,669	SUCC scripts.py:940 -- Ray runtime started.
# 2024-02-14 16:23:00,669	SUCC scripts.py:941 -- --------------------
# 2024-02-14 16:23:00,669	INFO scripts.py:943 -- To terminate the Ray runtime, run
# 2024-02-14 16:23:00,669	INFO scripts.py:944 --   ray stop
# 2024-02-14 16:23:00,669	INFO scripts.py:952 -- --block
# 2024-02-14 16:23:00,669	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 16:23:00,669	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# [2024-02-14 16:23:02,784 I 968714 968714] global_state_accessor.cc:432: This node has an IP address of 10.203.101.87, but we cannot find a local Raylet with the same address. This can happen when you connect to the Ray cluster with a different IP address or when connecting to a container.
# 2024-02-14 16:23:02,663	INFO scripts.py:926 -- Local node IP: 10.203.101.87
# 2024-02-14 16:23:02,802	SUCC scripts.py:939 -- --------------------
# 2024-02-14 16:23:02,802	SUCC scripts.py:940 -- Ray runtime started.
# 2024-02-14 16:23:02,802	SUCC scripts.py:941 -- --------------------
# 2024-02-14 16:23:02,802	INFO scripts.py:943 -- To terminate the Ray runtime, run
# 2024-02-14 16:23:02,802	INFO scripts.py:944 --   ray stop
# 2024-02-14 16:23:02,802	INFO scripts.py:952 -- --block
# 2024-02-14 16:23:02,802	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 16:23:02,802	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-02-14 16:23:05,804	INFO worker.py:1540 -- Connecting to existing Ray cluster at address: 10.203.101.85:6379...
# 2024-02-14 16:23:05,843	INFO worker.py:1715 -- Connected to Ray cluster. View the dashboard at 10.203.101.85:8265
# (worker_mistral_simplify pid=969015, ip=10.203.101.87)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 698.96 examples/s]
# (worker_mistral_simplify pid=969015, ip=10.203.101.87)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 2009.96 examples/s]
# (worker_mistral_simplify pid=969015, ip=10.203.101.87)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 1366.29 examples/s]
# (worker_mistral_simplify pid=969015, ip=10.203.101.87)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# (worker_mistral_simplify pid=969015, ip=10.203.101.87) /users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# (worker_mistral_simplify pid=969015, ip=10.203.101.87)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=528458)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# (worker_mistral_simplify pid=1702375, ip=10.203.101.86)
# Map:   3%|▎         | 1/33 [00:00<00:04,  7.58 examples/s]
# (worker_mistral_simplify pid=528458)
# Map:   3%|▎         | 1/33 [00:00<00:15,  2.12 examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 64.59 examples/s]
# (worker_mistral_simplify pid=1702375, ip=10.203.101.86)
# Map: 100%|██████████| 33/33 [00:00<00:00, 125.54 examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 109.54 examples/s]
# (worker_mistral_simplify pid=528458)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 1554.75 examples/s]
# (worker_mistral_simplify pid=528458)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 1339.00 examples/s]
# (worker_mistral_simplify pid=1702375, ip=10.203.101.86)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# (worker_mistral_simplify pid=1702375, ip=10.203.101.86)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=528458)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=1702375, ip=10.203.101.86)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:34<00:34, 34.74s/it]
# (worker_mistral_simplify pid=1702375, ip=10.203.101.86)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# ...
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1402-16h55_queue.log>
# Submitted batch job 38697494
# IP Head: 10.203.101.85:6379
# STARTING HEAD at dnagpu005
# 2024-02-14 16:55:14,388	INFO usage_lib.py:449 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-02-14 16:55:14,389	INFO scripts.py:744 -- Local node IP: 10.203.101.85
# 2024-02-14 16:55:19,126	SUCC scripts.py:781 -- --------------------
# 2024-02-14 16:55:19,126	SUCC scripts.py:782 -- Ray runtime started.
# 2024-02-14 16:55:19,126	SUCC scripts.py:783 -- --------------------
# 2024-02-14 16:55:19,126	INFO scripts.py:785 -- Next steps
# 2024-02-14 16:55:19,128	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-02-14 16:55:19,128	INFO scripts.py:791 --   ray start --address='10.203.101.85:6379'
# 2024-02-14 16:55:19,128	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-02-14 16:55:19,128	INFO scripts.py:802 -- import ray
# 2024-02-14 16:55:19,128	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.85')
# 2024-02-14 16:55:19,128	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-02-14 16:55:19,128	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.85:8265' ray job submit --working-dir . -- python my_script.py
# 2024-02-14 16:55:19,128	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-02-14 16:55:19,128	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-02-14 16:55:19,128	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-02-14 16:55:19,128	INFO scripts.py:835 --   ray stop
# 2024-02-14 16:55:19,128	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-02-14 16:55:19,128	INFO scripts.py:839 --   ray status
# 2024-02-14 16:55:19,128	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-02-14 16:55:19,128	INFO scripts.py:844 --   10.203.101.85:8265
# 2024-02-14 16:55:19,128	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-02-14 16:55:19,129	INFO scripts.py:952 -- --block
# 2024-02-14 16:55:19,129	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 16:55:19,129	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# STARTING WORKER 1 at dnagpu006
# [2024-02-14 16:55:44,615 I 1708314 1708314] global_state_accessor.cc:432: This node has an IP address of 10.203.101.86, but we cannot find a local Raylet with the same address. This can happen when you connect to the Ray cluster with a different IP address or when connecting to a container.
# 2024-02-14 16:55:44,508	INFO scripts.py:926 -- Local node IP: 10.203.101.86
# 2024-02-14 16:55:44,634	SUCC scripts.py:939 -- --------------------
# 2024-02-14 16:55:44,634	SUCC scripts.py:940 -- Ray runtime started.
# 2024-02-14 16:55:44,634	SUCC scripts.py:941 -- --------------------
# 2024-02-14 16:55:44,634	INFO scripts.py:943 -- To terminate the Ray runtime, run
# 2024-02-14 16:55:44,634	INFO scripts.py:944 --   ray stop
# 2024-02-14 16:55:44,634	INFO scripts.py:952 -- --block
# 2024-02-14 16:55:44,634	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 16:55:44,634	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# STARTING WORKER 2 at dnagpu007
# [2024-02-14 16:55:49,374 I 974877 974877] global_state_accessor.cc:432: This node has an IP address of 10.203.101.87, but we cannot find a local Raylet with the same address. This can happen when you connect to the Ray cluster with a different IP address or when connecting to a container.
# 2024-02-14 16:55:49,272	INFO scripts.py:926 -- Local node IP: 10.203.101.87
# 2024-02-14 16:55:49,392	SUCC scripts.py:939 -- --------------------
# 2024-02-14 16:55:49,393	SUCC scripts.py:940 -- Ray runtime started.
# 2024-02-14 16:55:49,393	SUCC scripts.py:941 -- --------------------
# 2024-02-14 16:55:49,393	INFO scripts.py:943 -- To terminate the Ray runtime, run
# 2024-02-14 16:55:49,393	INFO scripts.py:944 --   ray stop
# 2024-02-14 16:55:49,393	INFO scripts.py:952 -- --block
# 2024-02-14 16:55:49,393	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 16:55:49,393	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-02-14 16:55:52,525	INFO worker.py:1540 -- Connecting to existing Ray cluster at address: 10.203.101.85:6379...
# 2024-02-14 16:55:52,533	INFO worker.py:1715 -- Connected to Ray cluster. View the dashboard at 10.203.101.85:8265
# (worker_mistral_simplify pid=887208)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 531.32 examples/s]
# (worker_mistral_simplify pid=887208)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 1921.14 examples/s]
# (worker_mistral_simplify pid=887208)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# (worker_mistral_simplify pid=887208)
# Map: 100%|██████████| 33/33 [00:00<00:00, 242.78 examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 239.73 examples/s]
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86)
# Map: 100%|██████████| 33/33 [00:00<00:00, 1852.43 examples/s]
# (worker_mistral_simplify pid=975152, ip=10.203.101.87)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# (worker_mistral_simplify pid=975152, ip=10.203.101.87)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=975152, ip=10.203.101.87)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:07<00:07,  7.83s/it]
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 1245.53 examples/s] [repeated 5x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage() [repeated 2x across cluster]
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86)   return self.fget.__get__(instance, owner)() [repeated 2x across cluster]
# (worker_mistral_simplify pid=975152, ip=10.203.101.87)
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.24s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.63s/it]
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86) To disable this warning, you can either:
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86) 	- Avoid using `tokenizers` before the fork if possible
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (worker_mistral_simplify pid=887208)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:10<00:10, 10.34s/it] [repeated 2x across cluster]
# (worker_mistral_simplify pid=887208)
# Loading checkpoint shards: 100%|██████████| 2/2 [00:15<00:00,  7.08s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:15<00:00,  7.57s/it] [repeated 2x across cluster]
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86)
#   0%|          | 0/5 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=887208) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks... [repeated 5x across cluster]
# (worker_mistral_simplify pid=887208) To disable this warning, you can either: [repeated 5x across cluster]
# (worker_mistral_simplify pid=887208) 	- Avoid using `tokenizers` before the fork if possible [repeated 5x across cluster]
# (worker_mistral_simplify pid=887208) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false) [repeated 5x across cluster]
# (worker_mistral_simplify pid=887208)
#   0%|          | 0/5 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation. [repeated 2x across cluster]
# (worker_mistral_simplify pid=887208)
#  20%|██        | 1/5 [00:09<00:37,  9.35s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=887208)
#  40%|████      | 2/5 [00:19<00:29,  9.98s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86)
#  20%|██        | 1/5 [00:25<01:42, 25.66s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86)
#  40%|████      | 2/5 [00:34<00:46, 15.62s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86)
#  60%|██████    | 3/5 [00:43<00:25, 12.54s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=887208)
#  60%|██████    | 3/5 [00:43<00:32, 16.15s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86)
#  80%|████████  | 4/5 [00:56<00:12, 12.85s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=1708587, ip=10.203.101.86)
# 100%|██████████| 5/5 [00:59<00:00,  9.49s/it]
# 100%|██████████| 5/5 [00:59<00:00, 12.00s/it]
# (worker_mistral_simplify pid=887208)
#  80%|████████  | 4/5 [00:51<00:13, 13.11s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86)
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1/1 [00:00<00:00, 25.12 examples/s]
# (worker_mistral_simplify pid=887208)
# 100%|██████████| 5/5 [00:56<00:00, 10.17s/it]
# 100%|██████████| 5/5 [00:56<00:00, 11.33s/it]
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86)
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1/1 [00:00<00:00, 193.72 examples/s]
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86)
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1/1 [00:00<00:00, 229.99 examples/s]
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:07<00:07,  7.48s/it]
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86)
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.15s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.50s/it]
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86) To disable this warning, you can either:
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86) 	- Avoid using `tokenizers` before the fork if possible
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86) To disable this warning, you can either:
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86) 	- Avoid using `tokenizers` before the fork if possible
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86)
#   0%|          | 0/1 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=975152, ip=10.203.101.87)
#  20%|██        | 1/5 [01:26<05:46, 86.61s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=1709018, ip=10.203.101.86)
# 100%|██████████| 1/1 [00:03<00:00,  3.94s/it]
# 100%|██████████| 1/1 [00:03<00:00,  3.94s/it]
# (worker_mistral_simplify pid=975152, ip=10.203.101.87)
#  40%|████      | 2/5 [02:53<04:20, 86.75s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=975152, ip=10.203.101.87)
#  60%|██████    | 3/5 [04:20<02:53, 86.88s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=975152, ip=10.203.101.87)
#  80%|████████  | 4/5 [04:33<00:57, 57.90s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Job finished!
# Downloading result...
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: camembert-base
# Result downloaded!
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name camembert-base. Creating a new one with MEAN pooling.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# /home/lopilo/.cache/pypoetry/virtualenvs/lingorank-llm-wa__1Cox-py3.9/lib/python3.9/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.3.2 when using version 1.4.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Run iterative simplification
result = iterative_simplification(test_df.sample(100), bert=True)

# Save result
result.dropna().to_csv(
    os.path.join(
        pwd,
        "results",
        "text_simplification",
        "IterativeSimplification",
        "iterative_simplification_bert.csv",
    ),
    index=False,
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Serializing function and arguments...
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# Connecting to the cluster...
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# Writing slurmray server script...
# Downloading server...
# Running server...
# Installing slurmray server
# Requirement already satisfied: aiohttp-cors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: aiorwlock in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: bitsandbytes in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.42.0)
# Requirement already satisfied: black in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (24.1.1)
# Requirement already satisfied: colorful in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.5.6)
# Requirement already satisfied: datasets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.16.1)
# Requirement already satisfied: deepspeed in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.13.1)
# Requirement already satisfied: einops in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: fastapi in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.109.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: gpustat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: httptools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: inquirerpy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (0.3.4)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (20.11.0)
# Requirement already satisfied: jsonpointer in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (2.4)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (1.6.3)
# Requirement already satisfied: modcell in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.1.1)
# Requirement already satisfied: mysql-connector-python in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (8.3.0)
# Requirement already satisfied: openai in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (1.10.0)
# Requirement already satisfied: opencensus in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.11.4)
# Requirement already satisfied: pathtools in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.1.2)
# Requirement already satisfied: peft in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.7.1)
# Requirement already satisfied: py-spy in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (0.3.14)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (1.0.1)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (13.7.0)
# Requirement already satisfied: rouge-score in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (0.1.2)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.1.1)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: sentence-transformers in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (2.3.1)
# Requirement already satisfied: smart-open in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (6.4.0)
# Requirement already satisfied: tensorboardx in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (2.6.2.2)
# Requirement already satisfied: textstat in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.7.3)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.5.2)
# Requirement already satisfied: torch-tb-profiler in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (0.4.3)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (2.1.1)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (0.16.1)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (1.3.0)
# Requirement already satisfied: uvicorn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.27.0.post1)
# Requirement already satisfied: uvloop in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (0.19.0)
# Requirement already satisfied: virtualenv in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (20.25.0)
# Requirement already satisfied: wandb in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.16.2)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (0.21.0)
# Requirement already satisfied: webcolors in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (1.13)
# Requirement already satisfied: websockets in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (12.0)
# Requirement already satisfied: slurmray in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (3.5.7)
# Requirement already satisfied: torch==2.1.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 46)) (2.1.1)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (3.13.1)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (4.9.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (1.12)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (3.2.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (3.1.3)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.9/site-packages (from torch==2.1.1->-r requirements.txt (line 46)) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.venv/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.1->-r requirements.txt (line 46)) (12.3.101)
# Requirement already satisfied: aiohttp>=1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp-cors->-r requirements.txt (line 1)) (3.9.2)
# Requirement already satisfied: scipy in ./.venv/lib/python3.9/site-packages (from bitsandbytes->-r requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: tomli>=1.1.0 in ./.venv/lib/python3.9/site-packages (from black->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (1.26.3)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: huggingface-hub>=0.19.4 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: hjson in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: ninja in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (1.11.1.1)
# Requirement already satisfied: psutil in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (5.9.8)
# Requirement already satisfied: py-cpuinfo in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (9.0.0)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (2.5.3)
# Requirement already satisfied: pynvml in ./.venv/lib/python3.9/site-packages (from deepspeed->-r requirements.txt (line 7)) (11.5.0)
# Requirement already satisfied: starlette<0.36.0,>=0.35.0 in ./.venv/lib/python3.9/site-packages (from fastapi->-r requirements.txt (line 9)) (0.35.1)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (12.535.133)
# Requirement already satisfied: blessed>=1.17.1 in ./.venv/lib/python3.9/site-packages (from gpustat->-r requirements.txt (line 11)) (1.20.0)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from inquirerpy->-r requirements.txt (line 13)) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from inquirerpy->-r requirements.txt (line 13)) (3.0.43)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->-r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (1.16.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (2023.11.17)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (2.8.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (8.0.2)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (2.1.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.9/site-packages (from kaggle->-r requirements.txt (line 16)) (6.1.0)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.9/site-packages (from modcell->-r requirements.txt (line 17)) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (0.26.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 19)) (1.3.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from opencensus->-r requirements.txt (line 20)) (2.15.0)
# Requirement already satisfied: transformers in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 22)) (4.37.1)
# Requirement already satisfied: accelerate>=0.21.0 in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 22)) (0.26.1)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.9/site-packages (from peft->-r requirements.txt (line 22)) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 25)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->-r requirements.txt (line 25)) (2.17.2)
# Requirement already satisfied: absl-py in ./.venv/lib/python3.9/site-packages (from rouge-score->-r requirements.txt (line 26)) (2.1.0)
# Requirement already satisfied: nltk in ./.venv/lib/python3.9/site-packages (from rouge-score->-r requirements.txt (line 26)) (3.8.1)
# Requirement already satisfied: regex in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 27)) (2023.12.25)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from sacremoses->-r requirements.txt (line 27)) (1.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.venv/lib/python3.9/site-packages (from seaborn->-r requirements.txt (line 28)) (3.8.2)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from sentence-transformers->-r requirements.txt (line 29)) (1.4.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.9/site-packages (from sentence-transformers->-r requirements.txt (line 29)) (0.1.99)
# Requirement already satisfied: Pillow in ./.venv/lib/python3.9/site-packages (from sentence-transformers->-r requirements.txt (line 29)) (10.2.0)
# Requirement already satisfied: protobuf>=3.20 in ./.venv/lib/python3.9/site-packages (from tensorboardx->-r requirements.txt (line 31)) (4.23.4)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.9/site-packages (from textstat->-r requirements.txt (line 32)) (0.14.0)
# Requirement already satisfied: tensorboard!=2.1.0,>=1.15 in ./.venv/lib/python3.9/site-packages (from torch-tb-profiler->-r requirements.txt (line 34)) (2.15.1)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.9/site-packages (from uvicorn->-r requirements.txt (line 38)) (0.14.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in ./.venv/lib/python3.9/site-packages (from virtualenv->-r requirements.txt (line 40)) (0.3.8)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (3.1.41)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (1.39.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (0.4.0)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (1.3.3)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (58.1.0)
# Requirement already satisfied: appdirs>=1.4.3 in ./.venv/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 41)) (1.4.4)
# Requirement already satisfied: paramiko<4.0.0,>=3.3.1 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 45)) (3.4.0)
# Requirement already satisfied: pdoc3<0.11.0,>=0.10.0 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 45)) (0.10.0)
# Requirement already satisfied: pip-chill<2.0.0,>=1.0.3 in ./.venv/lib/python3.9/site-packages (from slurmray->-r requirements.txt (line 45)) (1.0.3)
# Requirement already satisfied: ray<3.0.0,>=2.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (2.9.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp>=1.1->aiohttp-cors->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 19)) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 19)) (1.2.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->-r requirements.txt (line 14)) (2.8.19.20240106)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->-r requirements.txt (line 11)) (0.2.13)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 41)) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (1.62.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (2.27.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 19)) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 25)) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.9/site-packages (from pandas->datasets->-r requirements.txt (line 6)) (2023.4)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (4.1.2)
# Requirement already satisfied: cryptography>=3.3 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (42.0.1)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/lib/python3.9/site-packages (from paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (1.5.0)
# Requirement already satisfied: mako in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: markdown>=3.0 in ./.venv/lib/python3.9/site-packages (from pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 45)) (3.5.2)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.9/site-packages (from pydantic->deepspeed->-r requirements.txt (line 7)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in ./.venv/lib/python3.9/site-packages (from pydantic->deepspeed->-r requirements.txt (line 7)) (2.14.6)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.9/site-packages (from ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (4.21.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (1.0.7)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (0.19.0)
# Requirement already satisfied: grpcio>=1.32.0 in ./.venv/lib/python3.9/site-packages (from ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (1.60.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (1.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (3.0.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.9/site-packages (from transformers->peft->-r requirements.txt (line 22)) (0.15.1)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach->kaggle->-r requirements.txt (line 16)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch==2.1.1->-r requirements.txt (line 46)) (2.1.4)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (7.0.7)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (5.5.1)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (7.14.2)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (6.29.0)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.9/site-packages (from jupyter->modcell->-r requirements.txt (line 17)) (8.1.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.9/site-packages (from python-slugify->kaggle->-r requirements.txt (line 16)) (1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 29)) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->torch==2.1.1->-r requirements.txt (line 46)) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.9/site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 41)) (5.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn->-r requirements.txt (line 28)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=3.0->pdoc3<0.11.0,>=0.10.0->slurmray->-r requirements.txt (line 45)) (7.0.1)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.1.6)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (5.14.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 17)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.venv/lib/python3.9/site-packages (from ipywidgets->jupyter->modcell->-r requirements.txt (line 17)) (3.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema->ray<3.0.0,>=2.7.1->ray[data,serve,train,tune]<3.0.0,>=2.7.1->slurmray->-r requirements.txt (line 45)) (0.17.1)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (4.12.3)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (0.9.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.12.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.9/site-packages (from notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.9/site-packages (from qtconsole->jupyter->modcell->-r requirements.txt (line 17)) (2.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4.0.0,>=3.3.1->slurmray->-r requirements.txt (line 45)) (2.21)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.19.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (4.9.0)
# Requirement already satisfied: argon2-cffi in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.5.2)
# Requirement already satisfied: overrides in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (7.7.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.18.0)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.2.2)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.9.14)
# Requirement already satisfied: fastjsonschema in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (2.19.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->-r requirements.txt (line 20)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard!=2.1.0,>=1.15->torch-tb-profiler->-r requirements.txt (line 34)) (3.2.2)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter->modcell->-r requirements.txt (line 17)) (2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->modcell->-r requirements.txt (line 17)) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->modcell->-r requirements.txt (line 17)) (0.2.2)
# Writing python script...
# Writing slurm script...
# No serialization done.
# Cluster detected, running on cluster...
# Canceling old jobs...
# Start to submit job!
# Job submitted! Script file is at: </users/hjamet/slurmray-server/.slogs/server/sbatch.sh>. Log file is at: </users/hjamet/slurmray-server/.slogs/server/server_1402-17h07.log>
# Start to monitor the queue... You can check the queue at: </users/hjamet/slurmray-server/.slogs/server/server_1402-17h07_queue.log>
# Submitted batch job 38698139
# IP Head: 10.203.101.85:6379
# STARTING HEAD at dnagpu005
# 2024-02-14 17:07:13,369	INFO usage_lib.py:449 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-02-14 17:07:13,370	INFO scripts.py:744 -- Local node IP: 10.203.101.85
# 2024-02-14 17:07:18,187	SUCC scripts.py:781 -- --------------------
# 2024-02-14 17:07:18,187	SUCC scripts.py:782 -- Ray runtime started.
# 2024-02-14 17:07:18,187	SUCC scripts.py:783 -- --------------------
# 2024-02-14 17:07:18,187	INFO scripts.py:785 -- Next steps
# 2024-02-14 17:07:18,189	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-02-14 17:07:18,189	INFO scripts.py:791 --   ray start --address='10.203.101.85:6379'
# 2024-02-14 17:07:18,189	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-02-14 17:07:18,189	INFO scripts.py:802 -- import ray
# 2024-02-14 17:07:18,189	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.85')
# 2024-02-14 17:07:18,189	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-02-14 17:07:18,189	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.85:8265' ray job submit --working-dir . -- python my_script.py
# 2024-02-14 17:07:18,189	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-02-14 17:07:18,189	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-02-14 17:07:18,189	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-02-14 17:07:18,189	INFO scripts.py:835 --   ray stop
# 2024-02-14 17:07:18,189	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-02-14 17:07:18,190	INFO scripts.py:839 --   ray status
# 2024-02-14 17:07:18,190	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-02-14 17:07:18,190	INFO scripts.py:844 --   10.203.101.85:8265
# 2024-02-14 17:07:18,190	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-02-14 17:07:18,190	INFO scripts.py:952 -- --block
# 2024-02-14 17:07:18,190	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 17:07:18,190	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# STARTING WORKER 1 at dnagpu006
# [2024-02-14 17:07:43,568 I 1709565 1709565] global_state_accessor.cc:432: This node has an IP address of 10.203.101.86, but we cannot find a local Raylet with the same address. This can happen when you connect to the Ray cluster with a different IP address or when connecting to a container.
# 2024-02-14 17:07:43,448	INFO scripts.py:926 -- Local node IP: 10.203.101.86
# 2024-02-14 17:07:43,575	SUCC scripts.py:939 -- --------------------
# 2024-02-14 17:07:43,575	SUCC scripts.py:940 -- Ray runtime started.
# 2024-02-14 17:07:43,575	SUCC scripts.py:941 -- --------------------
# 2024-02-14 17:07:43,575	INFO scripts.py:943 -- To terminate the Ray runtime, run
# 2024-02-14 17:07:43,575	INFO scripts.py:944 --   ray stop
# 2024-02-14 17:07:43,575	INFO scripts.py:952 -- --block
# 2024-02-14 17:07:43,575	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 17:07:43,575	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# STARTING WORKER 2 at dnagpu007
# [2024-02-14 17:07:48,289 I 976102 976102] global_state_accessor.cc:432: This node has an IP address of 10.203.101.87, but we cannot find a local Raylet with the same address. This can happen when you connect to the Ray cluster with a different IP address or when connecting to a container.
# 2024-02-14 17:07:48,186	INFO scripts.py:926 -- Local node IP: 10.203.101.87
# 2024-02-14 17:07:48,302	SUCC scripts.py:939 -- --------------------
# 2024-02-14 17:07:48,302	SUCC scripts.py:940 -- Ray runtime started.
# 2024-02-14 17:07:48,302	SUCC scripts.py:941 -- --------------------
# 2024-02-14 17:07:48,303	INFO scripts.py:943 -- To terminate the Ray runtime, run
# 2024-02-14 17:07:48,303	INFO scripts.py:944 --   ray stop
# 2024-02-14 17:07:48,303	INFO scripts.py:952 -- --block
# 2024-02-14 17:07:48,303	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 17:07:48,303	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-02-14 17:07:51,483	INFO worker.py:1540 -- Connecting to existing Ray cluster at address: 10.203.101.85:6379...
# 2024-02-14 17:07:51,489	INFO worker.py:1715 -- Connected to Ray cluster. View the dashboard at 10.203.101.85:8265
# (worker_mistral_simplify pid=891668)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# (worker_mistral_simplify pid=891668)
# Map: 100%|██████████| 33/33 [00:00<00:00, 518.17 examples/s]
# (worker_mistral_simplify pid=976378, ip=10.203.101.87)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 1896.03 examples/s]
# (worker_mistral_simplify pid=976378, ip=10.203.101.87)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 1252.14 examples/s]
# (worker_mistral_simplify pid=976378, ip=10.203.101.87)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# (worker_mistral_simplify pid=976378, ip=10.203.101.87)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=976378, ip=10.203.101.87)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:07<00:07,  7.83s/it]
# (worker_mistral_simplify pid=1709891, ip=10.203.101.86)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s] [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (worker_mistral_simplify pid=1709891, ip=10.203.101.86)
# Map: 100%|██████████| 33/33 [00:00<00:00, 1421.39 examples/s] [repeated 4x across cluster]
# (worker_mistral_simplify pid=1709891, ip=10.203.101.86)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 2061.42 examples/s] [repeated 2x across cluster]
# (worker_mistral_simplify pid=891668)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage() [repeated 2x across cluster]
# (worker_mistral_simplify pid=891668)   return self.fget.__get__(instance, owner)() [repeated 2x across cluster]
# (worker_mistral_simplify pid=976378, ip=10.203.101.87)
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.25s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.64s/it]
# (worker_mistral_simplify pid=976378, ip=10.203.101.87) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# ...
# 2024-02-14 17:36:28,805	INFO usage_lib.py:449 -- Usage stats collection is enabled by default without user confirmation because this terminal is detected to be non-interactive. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2024-02-14 17:36:28,805	INFO scripts.py:744 -- Local node IP: 10.203.101.85
# 2024-02-14 17:36:33,619	SUCC scripts.py:781 -- --------------------
# 2024-02-14 17:36:33,619	SUCC scripts.py:782 -- Ray runtime started.
# 2024-02-14 17:36:33,619	SUCC scripts.py:783 -- --------------------
# 2024-02-14 17:36:33,619	INFO scripts.py:785 -- Next steps
# 2024-02-14 17:36:33,621	INFO scripts.py:788 -- To add another node to this Ray cluster, run
# 2024-02-14 17:36:33,621	INFO scripts.py:791 --   ray start --address='10.203.101.85:6379'
# 2024-02-14 17:36:33,621	INFO scripts.py:800 -- To connect to this Ray cluster:
# 2024-02-14 17:36:33,621	INFO scripts.py:802 -- import ray
# 2024-02-14 17:36:33,621	INFO scripts.py:803 -- ray.init(_node_ip_address='10.203.101.85')
# 2024-02-14 17:36:33,621	INFO scripts.py:815 -- To submit a Ray job using the Ray Jobs CLI:
# 2024-02-14 17:36:33,621	INFO scripts.py:816 --   RAY_ADDRESS='http://10.203.101.85:8265' ray job submit --working-dir . -- python my_script.py
# 2024-02-14 17:36:33,621	INFO scripts.py:825 -- See https://docs.ray.io/en/latest/cluster/running-applications/job-submission/index.html
# 2024-02-14 17:36:33,621	INFO scripts.py:829 -- for more information on submitting Ray jobs to the Ray cluster.
# 2024-02-14 17:36:33,621	INFO scripts.py:834 -- To terminate the Ray runtime, run
# 2024-02-14 17:36:33,621	INFO scripts.py:835 --   ray stop
# 2024-02-14 17:36:33,621	INFO scripts.py:838 -- To view the status of the cluster, use
# 2024-02-14 17:36:33,621	INFO scripts.py:839 --   ray status
# 2024-02-14 17:36:33,621	INFO scripts.py:843 -- To monitor and debug Ray, view the dashboard at
# 2024-02-14 17:36:33,621	INFO scripts.py:844 --   10.203.101.85:8265
# 2024-02-14 17:36:33,621	INFO scripts.py:851 -- If connection to the dashboard fails, check your firewall settings and network configuration.
# 2024-02-14 17:36:33,622	INFO scripts.py:952 -- --block
# 2024-02-14 17:36:33,622	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 17:36:33,622	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# STARTING WORKER 1 at dnagpu006
# [2024-02-14 17:36:59,077 I 1715910 1715910] global_state_accessor.cc:432: This node has an IP address of 10.203.101.86, but we cannot find a local Raylet with the same address. This can happen when you connect to the Ray cluster with a different IP address or when connecting to a container.
# 2024-02-14 17:36:58,955	INFO scripts.py:926 -- Local node IP: 10.203.101.86
# 2024-02-14 17:36:59,086	SUCC scripts.py:939 -- --------------------
# 2024-02-14 17:36:59,087	SUCC scripts.py:940 -- Ray runtime started.
# 2024-02-14 17:36:59,087	SUCC scripts.py:941 -- --------------------
# 2024-02-14 17:36:59,087	INFO scripts.py:943 -- To terminate the Ray runtime, run
# 2024-02-14 17:36:59,087	INFO scripts.py:944 --   ray stop
# 2024-02-14 17:36:59,087	INFO scripts.py:952 -- --block
# 2024-02-14 17:36:59,087	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 17:36:59,087	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# STARTING WORKER 2 at dnagpu007
# [2024-02-14 17:37:03,801 I 981848 981848] global_state_accessor.cc:432: This node has an IP address of 10.203.101.87, but we cannot find a local Raylet with the same address. This can happen when you connect to the Ray cluster with a different IP address or when connecting to a container.
# 2024-02-14 17:37:03,698	INFO scripts.py:926 -- Local node IP: 10.203.101.87
# 2024-02-14 17:37:03,813	SUCC scripts.py:939 -- --------------------
# 2024-02-14 17:37:03,813	SUCC scripts.py:940 -- Ray runtime started.
# 2024-02-14 17:37:03,813	SUCC scripts.py:941 -- --------------------
# 2024-02-14 17:37:03,813	INFO scripts.py:943 -- To terminate the Ray runtime, run
# 2024-02-14 17:37:03,814	INFO scripts.py:944 --   ray stop
# 2024-02-14 17:37:03,814	INFO scripts.py:952 -- --block
# 2024-02-14 17:37:03,814	INFO scripts.py:953 -- This command will now block forever until terminated by a signal.
# 2024-02-14 17:37:03,814	INFO scripts.py:956 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2024-02-14 17:37:06,942	INFO worker.py:1540 -- Connecting to existing Ray cluster at address: 10.203.101.85:6379...
# 2024-02-14 17:37:06,950	INFO worker.py:1715 -- Connected to Ray cluster. View the dashboard at 10.203.101.85:8265
# (worker_mistral_simplify pid=920044)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 582.66 examples/s]
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# (worker_mistral_simplify pid=920044)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 1225.24 examples/s]
# (worker_mistral_simplify pid=920044)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 1247.96 examples/s]
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)
# Map: 100%|██████████| 33/33 [00:00<00:00, 697.37 examples/s]
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:07<00:07,  7.81s/it]
# (worker_mistral_simplify pid=1716189, ip=10.203.101.86)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Map: 100%|██████████| 33/33 [00:00<00:00, 1768.66 examples/s] [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (worker_mistral_simplify pid=1716189, ip=10.203.101.86)
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# (worker_mistral_simplify pid=1716189, ip=10.203.101.86)
# Map: 100%|██████████| 33/33 [00:00<00:00, 664.46 examples/s]
# (worker_mistral_simplify pid=1716189, ip=10.203.101.86)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage() [repeated 2x across cluster]
# (worker_mistral_simplify pid=1716189, ip=10.203.101.86)   return self.fget.__get__(instance, owner)() [repeated 2x across cluster]
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.25s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.63s/it]
# (worker_mistral_simplify pid=982171, ip=10.203.101.87) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# (worker_mistral_simplify pid=982171, ip=10.203.101.87) To disable this warning, you can either:
# (worker_mistral_simplify pid=982171, ip=10.203.101.87) 	- Avoid using `tokenizers` before the fork if possible
# (worker_mistral_simplify pid=982171, ip=10.203.101.87) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (worker_mistral_simplify pid=982171, ip=10.203.101.87) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# (worker_mistral_simplify pid=982171, ip=10.203.101.87) To disable this warning, you can either:
# (worker_mistral_simplify pid=982171, ip=10.203.101.87) 	- Avoid using `tokenizers` before the fork if possible
# (worker_mistral_simplify pid=982171, ip=10.203.101.87) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (worker_mistral_simplify pid=920044)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:10<00:10, 10.15s/it] [repeated 2x across cluster]
# (worker_mistral_simplify pid=920044)
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  6.81s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  7.31s/it] [repeated 2x across cluster]
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)
#   0%|          | 0/5 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=920044) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks... [repeated 4x across cluster]
# (worker_mistral_simplify pid=920044) To disable this warning, you can either: [repeated 4x across cluster]
# (worker_mistral_simplify pid=920044) 	- Avoid using `tokenizers` before the fork if possible [repeated 4x across cluster]
# (worker_mistral_simplify pid=920044) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false) [repeated 4x across cluster]
# (worker_mistral_simplify pid=920044)
#   0%|          | 0/5 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation. [repeated 2x across cluster]
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)
#  20%|██        | 1/5 [00:12<00:48, 12.23s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)
#  40%|████      | 2/5 [00:20<00:28,  9.61s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation. [repeated 2x across cluster]
# (worker_mistral_simplify pid=1716189, ip=10.203.101.86)
#  40%|████      | 2/5 [00:26<00:40, 13.41s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation. [repeated 2x across cluster]
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)
#  60%|██████    | 3/5 [00:34<00:23, 11.79s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=1716189, ip=10.203.101.86)
#  60%|██████    | 3/5 [00:35<00:22, 11.46s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=1716189, ip=10.203.101.86)
#  80%|████████  | 4/5 [00:44<00:10, 10.39s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation. [repeated 2x across cluster]
# (worker_mistral_simplify pid=1716189, ip=10.203.101.86)
# 100%|██████████| 5/5 [00:48<00:00,  7.86s/it]
# 100%|██████████| 5/5 [00:48<00:00,  9.61s/it]
# (worker_mistral_simplify pid=920044)
#  60%|██████    | 3/5 [00:48<00:32, 16.02s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)
#  80%|████████  | 4/5 [00:55<00:15, 15.31s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86)
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1/1 [00:00<00:00, 24.96 examples/s]
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86)
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1/1 [00:00<00:00, 210.44 examples/s]
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86)
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Map: 100%|██████████| 1/1 [00:00<00:00, 202.39 examples/s]
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/users/hjamet/slurmray-server/.venv/lib/python3.9/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86)   return self.fget.__get__(instance, owner)()
# (worker_mistral_simplify pid=982171, ip=10.203.101.87)
# 100%|██████████| 5/5 [00:59<00:00, 11.50s/it]
# 100%|██████████| 5/5 [00:59<00:00, 11.97s/it]
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86)
# Loading checkpoint shards:  50%|█████     | 1/2 [00:07<00:07,  7.60s/it]
# (worker_mistral_simplify pid=920044)
#  80%|████████  | 4/5 [01:01<00:15, 15.09s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86)
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.16s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.52s/it]
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86) To disable this warning, you can either:
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86) 	- Avoid using `tokenizers` before the fork if possible
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86) huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86) To disable this warning, you can either:
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86) 	- Avoid using `tokenizers` before the fork if possible
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86) 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# (worker_mistral_simplify pid=920044)
# 100%|██████████| 5/5 [01:07<00:00, 11.85s/it]
# 100%|██████████| 5/5 [01:07<00:00, 13.59s/it]
# (worker_mistral_simplify pid=1716618, ip=10.203.101.86)
#   0%|          | 0/1 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Job finished!
# Downloading result...
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: camembert-base
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name camembert-base. Creating a new one with MEAN pooling.
# Result downloaded!
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# /home/lopilo/.cache/pypoetry/virtualenvs/lingorank-llm-wa__1Cox-py3.9/lib/python3.9/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.3.2 when using version 1.4.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
